# %% [markdown]
# # LangGraph com MongoDB: Uma Análise Detalhada do Agente de IA
#
# ## 🎯 Visão Geral
#
# O código apresentado demonstra uma implementação sofisticada que combina LangGraph com MongoDB para criar um agente de IA capaz de realizar análises de dados e visualizações. Vamos explorar os aspectos fundamentais e benefícios desta integração.
#
# ## 🏗️ Fundamentos do LangGraph Utilizados
#
# ### 1. Estrutura de Estado
# * Implementação do `AgentState` usando `TypedDict`, seguindo as melhores práticas do LangGraph
# * Campos bem definidos para:
#   - Controle de fluxo (`accepted`, `revision`, `max_revision`)
#   - Armazenamento de dados (`results`, `database_info`)
#   - Visualização (`plot_needed`, `plot_type`, `plot_html`)
#
# ### 2. Nós do Grafo
# O código implementa diversos nós especializados:
# * `search_engineer_node`: Coleta informações do banco de dados
# * `query_writer_node`: Gera queries MongoDB
# * `qa_engineer_node`: Valida as queries
# * `chief_dba_node`: Fornece feedback para melhorias
# * `execute_query_node`: Executa as queries no MongoDB
# * `interpret_results_node`: Analisa os resultados
# * `plot_results_node`: Gera visualizações
#
# ### 3. Ciclos e Controle de Fluxo
# * Implementação de loops condicionais usando `add_conditional_edges`
# * Sistema de revisão com limite máximo de tentativas
# * Fluxo de trabalho cíclico para refinamento de queries
#
# ## 💪 Vantagens da Integração
#
# ### 1. Robustez e Confiabilidade
# * **Persistência de Estado**: Mantém o contexto entre execuções
# * **Tratamento de Erros**: Sistema robusto de handling de exceções
# * **Validação em Múltiplas Camadas**: QA, DBA, e execução segura
#
# ### 2. Flexibilidade e Extensibilidade
# * **Modular**: Cada nó tem responsabilidade única e bem definida
# * **Adaptável**: Fácil adição de novos tipos de análises ou visualizações
# * **Configurável**: Parâmetros ajustáveis para diferentes casos de uso
#
# ### 3. Capacidades Analíticas
# * **Visualização Dinâmica**: Suporte a múltiplos tipos de gráficos
# * **Interpretação Inteligente**: Análise contextual dos resultados
# * **Queries Adaptativas**: Refinamento baseado em feedback
#
# ### 4. Segurança e Controle
# * **Avaliação Segura**: Uso de `ast.literal_eval` para parsing seguro
# * **Conexão Controlada**: Gerenciamento adequado de conexões MongoDB
# * **Validação de Inputs**: Verificação em múltiplas camadas
#
# ## 🚀 Benefícios Práticos
#
# 1. **Produtividade**
#    - Automação de análises complexas
#    - Geração automática de visualizações
#    - Feedback rápido e iterativo
#
# 2. **Qualidade**
#    - Validação multi-camada
#    - Consistência nas análises
#    - Documentação automática dos resultados
#
# 3. **Usabilidade**
#    - Interface natural em linguagem humana
#    - Visualizações automáticas
#    - Feedback interpretativo
#
# ## 🔄 Ciclo de Vida da Execução
#
# 1. Recebimento da pergunta
# 2. Análise do contexto do banco
# 3. Geração e validação da query
# 4. Execução segura
# 5. Interpretação dos resultados
# 6. Geração de visualizações
# 7. Apresentação dos resultados
#
# ## 📊 Tipos de Análises Suportadas
#
# * Análises estatísticas
# * Visualizações comparativas
# * Detecção de outliers
# * Análises temporais
# * Agregações complexas
#
# Esta implementação demonstra como o LangGraph pode ser utilizado para criar um sistema robusto e flexível de análise de dados, combinando a poder do MongoDB com processamento de linguagem natural e visualização de dados.

# %% [markdown]
# # MongoDB vs Bancos Relacionais: Vantagens do NoSQL
#
# ## 💪 Principais Vantagens
#
# ### 1. Flexibilidade de Schema
# * **Schema Dinâmico**: Documentos na mesma coleção podem ter estruturas diferentes
# * **Evolução Natural**: Facilidade para adicionar ou remover campos sem migrações complexas
# * **Adaptabilidade**: Ideal para dados não estruturados ou semi-estruturados
#
# ### 2. Escalabilidade
# * **Escalabilidade Horizontal**: Facilidade para distribuir dados entre múltiplos servidores
# * **Sharding Nativo**: Particionamento automático de dados
# * **Alta Performance**: Melhor desempenho em grandes volumes de dados
#
# ### 3. Performance
# * **Consultas Otimizadas**: Documentos completos em uma única leitura
# * **Índices Flexíveis**: Suporte a diversos tipos de índices
# * **Menos JOINs**: Dados relacionados podem ser embutidos no mesmo documento
#
# ### 4. Desenvolvimento Ágil
# * **JSON/BSON**: Formato natural para desenvolvedores
# * **Menos Código**: Redução na complexidade do mapeamento objeto-relacional
# * **Prototipagem Rápida**: Ideal para MVPs e desenvolvimento iterativo
#
# ## 🎯 Casos de Uso Ideais
# * Aplicações em tempo real
# * Big Data e análise de dados
# * Conteúdo gerado por usuários
# * IoT e dados de sensores
# * Catálogos de produtos
# * Sistemas de gerenciamento de conteúdo
#
# ## 💡 Considerações
# Enquanto bancos relacionais são excelentes para dados altamente estruturados e transações complexas, o MongoDB brilha em cenários que exigem flexibilidade, escalabilidade e performance com grandes volumes de dados não estruturados.

# %% [markdown]
# Como membro da Scoras Tecnologia Digital Ltda, tenho tido a oportunidade de trabalhar com diversas tecnologias de banco de dados, incluindo DuckDB e MongoDB. A escolha entre esses dois sistemas depende muito das necessidades específicas do projeto em questão. Vou detalhar os prós e contras de cada um, assim como os cenários nos quais eles se destacam.
#
# ## DuckDB
#
# **Visão Geral:**
# DuckDB é um sistema de gerenciamento de banco de dados analítico em-processo, otimizado para consultas analíticas rápidas e complexas. É frequentemente comparado ao SQLite, mas focado em cargas de trabalho analíticas.
#
# **Prós:**
#
# - **Performance Analítica:** Excelente desempenho para consultas analíticas devido à sua arquitetura em coluna.
# - **Facilidade de Integração:** Sendo um banco de dados embutido, pode ser facilmente integrado em aplicativos existentes sem a necessidade de um servidor separado.
# - **Zero Configuração:** Não requer instalação ou configuração complexa, o que acelera o desenvolvimento.
# - **Suporte a SQL Padrão:** Utiliza SQL padrão, facilitando a adoção por equipes já familiarizadas com SQL.
#
# **Contras:**
#
# - **Escalabilidade Limitada:** Não é ideal para aplicações que requerem escalabilidade horizontal ou ambientes distribuídos.
# - **Funcionalidades Limitadas para OLTP:** Não é otimizado para operações transacionais intensas.
# - **Comunidade e Ecossistema Menores:** Comparado a sistemas mais populares, tem uma comunidade menor, o que pode limitar o suporte e os recursos disponíveis.
#
# ## MongoDB
#
# **Visão Geral:**
# MongoDB é um banco de dados NoSQL orientado a documentos que armazena dados em formato BSON (uma extensão binária de JSON). É conhecido por sua flexibilidade e escalabilidade.
#
# **Prós:**
#
# - **Flexibilidade de Esquema:** Permite alterações rápidas na estrutura dos dados sem a necessidade de migrações complexas.
# - **Escalabilidade Horizontal:** Projetado para escalar facilmente em clusters distribuídos.
# - **Alto Desempenho em Operações de Escrita:** Ótimo para aplicações com grande volume de inserções e atualizações.
# - **Ecossistema Rico:** Possui uma ampla comunidade e muitas ferramentas de suporte.
#
# **Contras:**
#
# - **Consultas Analíticas Menos Eficientes:** Não é otimizado para consultas analíticas complexas.
# - **Consistência Eventual:** Em configurações distribuídas, pode operar com consistência eventual, o que nem sempre é desejável.
# - **Curva de Aprendizado:** Requer uma compreensão diferente em relação aos bancos de dados relacionais tradicionais.
#
# ## Cenários de Uso
#
# **Quando Optar por DuckDB:**
#
# - **Análises de Dados Localizadas:** Ideal para aplicações que necessitam de análises de dados embutidas no aplicativo sem dependências externas.
# - **Processamento de Dados em Lote:** Quando há necessidade de processar grandes volumes de dados em lote com rapidez.
# - **Ambientes com Recursos Limitados:** Aplicações que precisam ser leves e não podem suportar a sobrecarga de um servidor de banco de dados separado.
#
# **Quando Optar por MongoDB:**
#
# - **Aplicações Web Escaláveis:** Ideal para serviços que precisam escalar horizontalmente para suportar muitos usuários.
# - **Dados Não Estruturados ou Semiestruturados:** Quando a flexibilidade do esquema é necessária.
# - **Prototipagem Rápida:** Permite desenvolvedores iterarem rapidamente sem se preocupar com a rigidez de um esquema relacional.
#
# ## Parecer Técnico
#
# Em nossa experiência na Scoras Tecnologia Digital Ltda, a escolha depende muito do tipo de dados e das necessidades da aplicação:
#
# - **Para Aplicações Analíticas:** Se o projeto envolve análise intensiva de dados estruturados e requer consultas SQL complexas, o DuckDB é uma excelente opção pela sua performance e facilidade de integração.
#
# - **Para Aplicações Orientadas a Documentos:** Se a aplicação lida com dados semiestruturados ou requer flexibilidade para alterar o esquema dos dados frequentemente, o MongoDB oferece a agilidade necessária.
#
# - **Considerações sobre Escalabilidade:** Para aplicações que preveem um crescimento rápido e precisam escalar horizontalmente, especialmente na nuvem, o MongoDB oferece ferramentas e recursos mais maduros.
#
# - **Recursos e Suporte:** Se o projeto se beneficiaria de uma comunidade ampla e recursos abundantes, o MongoDB, sendo mais estabelecido, pode ser mais vantajoso.
#
# ## Conclusão
#
# A decisão entre DuckDB e MongoDB deve ser guiada pelos requisitos específicos do projeto. O DuckDB se destaca em cenários analíticos embutidos e onde a simplicidade é valorizada. O MongoDB é mais adequado para aplicações que exigem flexibilidade de dados, escalabilidade e um ecossistema robusto. Na Scoras Tecnologia Digital Ltda, avaliamos cuidadosamente as necessidades de cada projeto para recomendar a solução que melhor alinha desempenho, escalabilidade e eficiência no desenvolvimento.

# %%
#!pip install langchain-openai
#!pip install langgraph
#!pip install pymongo
#!pip install matplotlib
#!pip install dnspython
#!pip install seaborn

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# Defina a string de conexão e o nome do banco de dados
CONNECTION_STRING = "mongodb://ecommerce_user:senha123@localhost:27017/ecommerce?authSource=ecommerce"
DATABASE_NAME = "ecommerce"

def test_mongodb_connection():
    """Testa a conexão com o MongoDB e lista informações básicas."""
    try:
        # Conectar ao MongoDB
        client = MongoClient(CONNECTION_STRING, serverSelectionTimeoutMS=5000)
        # Tentar obter informações do servidor
        server_info = client.server_info()
        print("Conexão com o MongoDB estabelecida com sucesso.")
        print(f"Versão do servidor: {server_info['version']}")
        
        # Listar bancos de dados disponíveis
        print("\nBancos de dados disponíveis:")
        print(client.list_database_names())
        
        # Acessar o banco de dados específico
        db = client[DATABASE_NAME]
        
        # Listar coleções no banco de dados
        print(f"\nColeções no banco de dados '{DATABASE_NAME}':")
        collections = db.list_collection_names()
        print(collections)
        
        # Contar documentos em cada coleção
        for collection_name in collections:
            collection = db[collection_name]
            count = collection.count_documents({})
            print(f"Coleção '{collection_name}' tem {count} documentos.")
        
        # Fechar a conexão
        client.close()
        
    except ConnectionFailure as e:
        print("Falha ao conectar-se ao MongoDB:")
        print(e)
    except Exception as e:
        print("Erro ao testar a conexão com o MongoDB:")
        print(e)

# Executar o teste
test_mongodb_connection()
# Out:
# Conexão com o MongoDB estabelecida com sucesso.
# Versão do servidor: 6.0.15
#
# Bancos de dados disponíveis:
# ['ecommerce']
#
# Coleções no banco de dados 'ecommerce':
# ['clientes', 'produtos', 'pedidos']
# Coleção 'clientes' tem 1200 documentos.
# Coleção 'produtos' tem 700 documentos.
# Coleção 'pedidos' tem 1200 documentos.

# %%
# Importações necessárias
import warnings
warnings.filterwarnings('ignore')

import os
import io
import base64
import json
import re
import matplotlib.pyplot as plt
import seaborn as sns  # Importar seaborn para gráficos avançados
from IPython.display import display, HTML
from typing_extensions import TypedDict
from typing import List, Dict, Any, Annotated

# Importações do LangGraph e LangChain
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, END, START
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import SystemMessage, HumanMessage

# Importações do MongoDB
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# Importação de segurança para avaliação segura de expressões
import ast

# Configuração do ambiente (defina sua chave de API da OpenAI)
os.environ['OPENAI_API_KEY'] = 'Coloque sua chave de API da OpenAI aqui'  # Substitua pela sua chave de API

# Definir o modelo de linguagem
model = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

# Definir o estado do agente usando TypedDict
class AgentState(TypedDict):
    question: str
    database_info: str
    database: str
    query: str
    reflect: Annotated[List[str], "add"]
    accepted: bool
    revision: int
    max_revision: int
    results: List[Dict[str, Any]]
    interpretation: str
    plot_needed: bool
    plot_type: str  # Novo campo para o tipo de gráfico
    plot_html: str
    error: str

# Configuração da conexão com o MongoDB
CONNECTION_STRING = "mongodb://ecommerce_user:senha123@localhost:27017/ecommerce?authSource=ecommerce"
DATABASE_NAME = "ecommerce"

# Função para verificar a conexão com o MongoDB
def check_mongodb_connection():
    """Verifica se a conexão com o MongoDB está estabelecida corretamente."""
    try:
        client = MongoClient(CONNECTION_STRING, serverSelectionTimeoutMS=3000)
        client.admin.command('ping')
        client.close()
        print("Conexão com o MongoDB estabelecida com sucesso.")
    except ConnectionFailure:
        print("Falha ao conectar-se ao MongoDB. Verifique se o serviço está em execução e as credenciais estão corretas.")

# Chamar a função de verificação de conexão
check_mongodb_connection()

# Função para obter informações do banco de dados
def get_database_info():
    """Obtém informações sobre as coleções e campos disponíveis no banco de dados."""
    client = MongoClient(CONNECTION_STRING)
    db = client[DATABASE_NAME]
    
    info = "Coleções disponíveis:\n"
    
    # Listar coleções e seus campos
    for collection_name in db.list_collection_names():
        info += f"\nColeção: {collection_name}\n"
        # Pegar um documento de exemplo para ver os campos
        sample = db[collection_name].find_one()
        if sample:
            info += "Campos:\n"
            for field in sample.keys():
                if field != "_id":  # Ignorar o campo _id
                    info += f" - {field}\n"
    
    client.close()
    return info

# Definir os nós para o LangGraph

def search_engineer_node(state: AgentState):
    """Obtém informações sobre o banco de dados e atualiza o estado."""
    state['database_info'] = get_database_info()
    state['database'] = DATABASE_NAME
    return state

def query_writer_node(state: AgentState):
    """Gera a query MongoDB em formato de dicionário Python, incluindo o nome da coleção."""
    role_prompt = """
Você é um especialista em MongoDB e PyMongo. Sua tarefa é escrever uma query MongoDB em formato de dicionário Python que responda à pergunta do usuário.

A query deve:
- Usar a sintaxe de dicionário do Python compatível com PyMongo.
- Incluir o nome da coleção a ser consultada, usando a chave 'collection'.
- Utilizar os nomes das coleções e campos conforme definidos no banco de dados.
- Retornar apenas o dicionário Python que representa a query, sem cercas de código ou texto adicional.
- Não incluir cercas de código, anotações de linguagem (como ```python) ou qualquer texto extra.

Por exemplo, para contar o número de produtos em cada categoria na coleção 'produtos', a query seria:

{
    'collection': 'produtos',
    'aggregate': [
        {
            '$group': {
                '_id': '$categoria',
                'total_produtos': { '$sum': 1 }
            }
        }
    ]
}
"""

    instruction = f"Informações do banco de dados:\n{state['database_info']}\n"
    if len(state['reflect']) > 0:
        instruction += f"Considere os seguintes feedbacks:\n{chr(10).join(state['reflect'])}\n"
    instruction += f"Escreva a query MongoDB em formato de dicionário Python que responda à seguinte pergunta: {state['question']}\n"

    messages = [
        SystemMessage(content=role_prompt),
        HumanMessage(content=instruction)
    ]

    response = model.invoke(messages)
    state['query'] = response.content.strip()
    state['revision'] += 1
    return state

def qa_engineer_node(state: AgentState):
    """Verifica se a query MongoDB está correta."""
    role_prompt = """
Você é um engenheiro de QA especializado em MongoDB. Sua tarefa é verificar se a query fornecida responde corretamente à pergunta do usuário.
"""

    instruction = f"Com base nas seguintes informações do banco de dados:\n{state['database_info']}\n"
    instruction += f"E na seguinte query MongoDB:\n{state['query']}\n"
    instruction += f"Verifique se a query pode completar a tarefa: {state['question']}\n"
    instruction += "Responda 'ACEITO' se estiver correta ou 'REJEITADO' se não estiver.\n"

    messages = [
        SystemMessage(content=role_prompt),
        HumanMessage(content=instruction)
    ]

    response = model.invoke(messages)
    state['accepted'] = 'ACEITO' in response.content.upper()
    return state

def chief_dba_node(state: AgentState):
    """Fornece feedback para melhorar a query MongoDB."""
    role_prompt = """
Você é um DBA experiente, especialista em MongoDB. Sua tarefa é fornecer feedback detalhado para melhorar a query fornecida.
"""

    instruction = f"Com base nas seguintes informações do banco de dados:\n{state['database_info']}\n"
    instruction += f"E na seguinte query MongoDB:\n{state['query']}\n"
    instruction += f"Por favor, forneça recomendações para melhorar a query para a tarefa: {state['question']}\n"

    messages = [
        SystemMessage(content=role_prompt),
        HumanMessage(content=instruction)
    ]

    response = model.invoke(messages)
    state['reflect'].append(response.content)
    return state

def execute_query_node(state: AgentState):
    """Executa a query MongoDB usando PyMongo."""
    client = MongoClient(CONNECTION_STRING)
    db = client[state['database']]

    try:
        # Limpar a query removendo cercas de código e texto adicional
        query_str = state['query'].strip()

        # Remover cercas de código usando expressões regulares
        query_str = re.sub(r'^```.*?$', '', query_str, flags=re.MULTILINE)
        query_str = query_str.strip('`').strip()

        # Avaliar o dicionário da query de forma segura
        query_dict = ast.literal_eval(query_str)

        # Obter a coleção a ser consultada
        if isinstance(query_dict, dict):
            collection_name = query_dict.get('collection')
            if not collection_name:
                raise ValueError("A query deve especificar a coleção no formato {'collection': 'nome_da_colecao', ...}")
            collection = db[collection_name]

            # Obter filtros e outras informações
            query_filter = query_dict.get('filter', {})
            query_projection = query_dict.get('projection')
            query_aggregate = query_dict.get('aggregate')

            # Executar a query de acordo com o tipo
            if query_aggregate:
                # Operação de agregação
                pipeline = query_aggregate
                cursor = collection.aggregate(pipeline)
            else:
                # Consulta padrão find()
                cursor = collection.find(query_filter, query_projection)

            # Obter os resultados
            state['results'] = list(cursor)
        else:
            raise ValueError("Formato de query não suportado.")

        # Serializar os resultados para JSON
        state['results'] = json.loads(json.dumps(state['results'], default=str))

        # Adicionar informações de debug
        print(f"Query executada com sucesso. Resultados: {len(state['results'])} documentos.")

    except Exception as e:
        print(f"Erro na execução da query: {str(e)}")
        state['results'] = []
        state['error'] = str(e)
    finally:
        client.close()

    return state

def interpret_results_node(state: AgentState):
    """Interpreta os resultados da query e sugere se um gráfico é necessário."""
    role_prompt = """
Você é um assistente especializado em interpretar resultados de queries MongoDB e explicá-los em linguagem natural.
Sua tarefa é:
- Analisar os resultados da query e fornecer uma resposta clara e concisa à pergunta original do usuário.
- Se houver dados numéricos ,categorias para comparar, precos, quantidade, e etc, sugira um tipo de gráfico adequado (por exemplo, gráfico de barras, gráfico de pizza, gráfico de dispersão, boxplot, violin plot, etc.).
- Seja criterioso na sugestão de gráficos e sugira apenas quando for relevante. Apenas comente sobre a sugestão de gráfico se o grafico tiver sido feito, caso contrario, nao comente sobre a sugestão de grafico.
- Retorne sua resposta no seguinte formato:

Interpretação: <sua interpretação aqui>
Sugestão de gráfico: <tipo de gráfico sugerido ou 'Nenhum' se não for aplicável>
"""

    instruction = f"Pergunta original: {state['question']}\n"
    instruction += f"Resultados da query: {state['results']}\n"
    if state.get('error'):
        instruction += f"Erro encontrado: {state['error']}\n"
    instruction += "Por favor, interprete esses resultados e sugira um tipo de gráfico se aplicável e feito, seguindo as instruções acima. Caso o grafico nao tenha sido feito, nao comente sobre a sugestão de grafico."

    messages = [
        SystemMessage(content=role_prompt),
        HumanMessage(content=instruction)
    ]

    response = model.invoke(messages)
    response_content = response.content.strip()

    # Processar a resposta para extrair interpretação e sugestão de gráfico
    interpretation = ''
    plot_suggestion = ''
    lines = response_content.split('\n')
    for line in lines:
        if line.startswith('Interpretação:'):
            interpretation = line[len('Interpretação:'):].strip()
        elif line.startswith('Sugestão de gráfico:'):
            plot_suggestion = line[len('Sugestão de gráfico:'):].strip()

    state['interpretation'] = interpretation
    plot_suggestion_lower = plot_suggestion.lower()
    if plot_suggestion_lower != 'nenhum':
        state['plot_needed'] = True
        state['plot_type'] = plot_suggestion_lower
    else:
        state['plot_needed'] = False
        state['plot_type'] = ''
    return state

def plot_results_node(state: AgentState):
    """Gera visualizações dos resultados, se necessário."""
    if not state['plot_needed']:
        state['plot_html'] = ''
        return state

    try:
        results = state['results']
        plot_type = state.get('plot_type', '').lower()
        if not results:
            print("Sem resultados para plotar.")
            return state

        # Limpar qualquer figura anterior
        plt.clf()
        plt.close('all')

        # Criar nova figura
        plt.figure(figsize=(10, 6))

        # Verificar se os resultados são adequados para plotagem
        if isinstance(results, list) and len(results) > 0:
            # Usar cores diferentes
            cmap = plt.get_cmap('tab20')
            colors = cmap.colors

            if plot_type == 'gráfico de barras' or plot_type == 'bar':
                # Gráfico de barras
                if '_id' in results[0]:
                    categories = [str(item['_id']) for item in results]
                    value_keys = [k for k in results[0].keys() if k != '_id' and isinstance(results[0][k], (int, float))]
                    if value_keys:
                        value_key = value_keys[0]
                        counts = [item.get(value_key, 0) for item in results]
                        plt.bar(categories, counts, color=colors[:len(categories)])
                        plt.title(f"{value_key.replace('_', ' ').title()} por Categoria")
                        plt.xlabel("Categorias")
                        plt.ylabel(value_key.replace('_', ' ').title())
                        plt.xticks(rotation=45)
                    else:
                        print("Nenhum valor numérico encontrado para plotagem.")
                        return state
                else:
                    print("Formato de dados não suportado para gráfico de barras.")
                    return state
            elif plot_type == 'gráfico de pizza' or plot_type == 'pie':
                # Gráfico de pizza
                if '_id' in results[0]:
                    labels = [str(item['_id']) for item in results]
                    value_keys = [k for k in results[0].keys() if k != '_id' and isinstance(results[0][k], (int, float))]
                    if value_keys:
                        value_key = value_keys[0]
                        sizes = [item.get(value_key, 0) for item in results]
                        plt.pie(sizes, labels=labels, colors=colors[:len(labels)], autopct='%1.1f%%', startangle=140)
                        plt.title(f"Distribuição de {value_key.replace('_', ' ').title()}")
                        plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
                    else:
                        print("Nenhum valor numérico encontrado para plotagem.")
                        return state
                else:
                    print("Formato de dados não suportado para gráfico de pizza.")
                    return state
            elif plot_type == 'gráfico de dispersão' or plot_type == 'scatter plot':
                # Gráfico de dispersão
                # Procurar duas chaves numéricas para plotar
                numeric_keys = [k for k in results[0].keys() if isinstance(results[0][k], (int, float))]
                if len(numeric_keys) >= 2:
                    x_key = numeric_keys[0]
                    y_key = numeric_keys[1]
                    x_values = [item.get(x_key, 0) for item in results]
                    y_values = [item.get(y_key, 0) for item in results]
                    plt.scatter(x_values, y_values, c=colors[0])
                    plt.title(f"{y_key.replace('_', ' ').title()} vs {x_key.replace('_', ' ').title()}")
                    plt.xlabel(x_key.replace('_', ' ').title())
                    plt.ylabel(y_key.replace('_', ' ').title())
                else:
                    print("Dados insuficientes para gráfico de dispersão.")
                    return state
            elif plot_type == 'boxplot' or plot_type == 'gráfico de caixa':
                # Boxplot
                numeric_keys = [k for k in results[0].keys() if isinstance(results[0][k], (int, float))]
                if numeric_keys:
                    data = [item.get(numeric_keys[0], 0) for item in results]
                    plt.boxplot(data)
                    plt.title(f"Boxplot de {numeric_keys[0].replace('_', ' ').title()}")
                else:
                    print("Nenhum valor numérico encontrado para boxplot.")
                    return state
            elif plot_type == 'violin plot' or plot_type == 'gráfico de violino':
                # Violin plot
                sns.set(style="whitegrid")
                numeric_keys = [k for k in results[0].keys() if isinstance(results[0][k], (int, float))]
                if numeric_keys:
                    data = [item.get(numeric_keys[0], 0) for item in results]
                    sns.violinplot(y=data)
                    plt.title(f"Violin Plot de {numeric_keys[0].replace('_', ' ').title()}")
                else:
                    print("Nenhum valor numérico encontrado para violin plot.")
                    return state
            else:
                print(f"Tipo de gráfico '{plot_type}' não suportado ou não reconhecido.")
                return state
        else:
            print("Formato de dados não suportado para visualização.")
            return state

        # Ajustar layout
        plt.tight_layout()

        # Salvar em buffer
        buffer = io.BytesIO()
        plt.savefig(buffer, format='png', dpi=300, bbox_inches='tight')
        buffer.seek(0)

        # Converter para base64
        image_base64 = base64.b64encode(buffer.getvalue()).decode('utf-8')

        # Criar HTML do gráfico
        state['plot_html'] = f'''
        <div class="plot-container">
            <img src="data:image/png;base64,{image_base64}" 
                 alt="Gráfico"
                 style="width:100%; max-width:800px; margin:0 auto; display:block;">
        </div>
        '''

        # Limpar
        plt.close('all')

    except Exception as e:
        print(f"Erro ao gerar gráfico: {str(e)}")
        state['plot_html'] = ''

    return state

# Construir o LangGraph
builder = StateGraph(AgentState)

# Adicionar nós ao grafo
builder.add_node('search_engineer', search_engineer_node)
builder.add_node('query_writer', query_writer_node)
builder.add_node('qa_engineer', qa_engineer_node)
builder.add_node('chief_dba', chief_dba_node)
builder.add_node('execute_query', execute_query_node)
builder.add_node('interpret_results', interpret_results_node)
builder.add_node('plot_results', plot_results_node)

# Definir as arestas entre os nós
builder.add_edge(START, 'search_engineer')
builder.add_edge('search_engineer', 'query_writer')
builder.add_edge('query_writer', 'qa_engineer')

# Aresta condicional do qa_engineer
builder.add_conditional_edges(
    'qa_engineer',
    lambda state: 'execute_query' if state['accepted'] or state['revision'] >= state['max_revision'] else 'chief_dba',
    {'execute_query': 'execute_query', 'chief_dba': 'chief_dba'}
)

builder.add_edge('chief_dba', 'query_writer')
builder.add_edge('execute_query', 'interpret_results')
builder.add_edge('interpret_results', 'plot_results')
builder.add_edge('plot_results', END)

# Definir o ponto de entrada
builder.set_entry_point('search_engineer')

# Compilar o grafo com um checkpointer
memory = MemorySaver()
graph = builder.compile(checkpointer=memory)

# Função para processar uma pergunta usando o grafo
def process_question(question):
    """Processa a pergunta do usuário através do grafo e exibe os resultados."""
    initial_state = {
        'question': question,
        'database_info': '',
        'database': '',
        'query': '',
        'reflect': [],
        'accepted': False,
        'revision': 0,
        'max_revision': 2,
        'results': [],
        'interpretation': '',
        'plot_needed': False,
        'plot_type': '',  # Inicializar plot_type
        'plot_html': '',
        'error': ''
    }
    thread = {'configurable': {'thread_id': '1'}}
    for _ in graph.stream(initial_state, thread):
        pass
    # Obter o estado final
    final_state = graph.get_state(thread).values

    # Exibir os resultados
    print('Query MongoDB Gerada:\n', final_state['query'])
    print('\nResultados da Query:')
    if final_state['results']:
        print(json.dumps(final_state['results'], indent=2, ensure_ascii=False))
    else:
        print('Nenhum resultado ou erro na execução da query.')
    
    print('\nInterpretação:')
    print(final_state['interpretation'])
    
    if final_state.get('plot_html'):
        display(HTML(final_state['plot_html']))
    else:
        print('Nenhum gráfico gerado.')
# Out:
# Conexão com o MongoDB estabelecida com sucesso.

# %%
pergunta = "Faca um grafico de pizza a quantidade de produtos por categoria em relacao a quantidade total"
process_question(pergunta)
# Out:
# Query executada com sucesso. Resultados: 5 documentos.
# Query MongoDB Gerada:
#  {
#     'collection': 'produtos',
#     'aggregate': [
#         {
#             '$group': {
#                 '_id': '$categoria',
#                 'total_produtos': { '$sum': '$estoque' }
#             }
#         },
#         {
#             '$group': {
#                 '_id': None,
#                 'total_estoque': { '$sum': '$total_produtos' }
#             }
#         },
#         {
#             '$lookup': {
#                 'from': 'produtos',
#                 'pipeline': [
#                     {
#                         '$group': {
#                             '_id': '$categoria',
#                             'total_produtos': { '$sum': '$estoque' }
#                         }
#                     },
#                     {
#                         '$addFields': {
#                             'porcentagem': {
#                                 '$multiply': [
#                                     { '$divide': ['$total_produtos', '$total_estoque'] },
#                                     100
#                                 ]
#                             }
#                         }
#                     },
#                     {
#                         '$project': {
#                             'categoria': '$_id',
#                             'porcentagem': 1
#                         }
#                     }
#                 ],
#                 'as': 'produtos_categoria'
#             }
#         },
#         {
#             '$unwind': '$produtos_categoria'
#         },
#         {
#             '$replaceRoot': { 'newRoot': '$produtos_categoria' }
#         }
#     ]
# }
#
# Resultados da Query:
# [
#   {
#     "_id": "Roupas",
#     "porcentagem": null,
#     "categoria": "Roupas"
#   },
#   {
#     "_id": "Eletrônicos",
#     "porcentagem": null,
#     "categoria": "Eletrônicos"
#   },
#   {
#     "_id": "Móveis",
#     "porcentagem": null,
#     "categoria": "Móveis"
#   },
#   {
#     "_id": "Alimentos",
#     "porcentagem": null,
#     "categoria": "Alimentos"
#   },
#   {
#     "_id": "Livros",
#     "porcentagem": null,
#     "categoria": "Livros"
#   }
# ]
#
# Interpretação:
# Os resultados da query mostram que existem cinco categorias de produtos: Roupas, Eletrônicos, Móveis, Alimentos e Livros. No entanto, não foram fornecidas informações sobre a quantidade de produtos em cada categoria ou a porcentagem em relação ao total, o que impede uma análise mais detalhada sobre a distribuição dos produtos por categoria.
# Nenhum gráfico gerado.

# %%
pergunta = "Faca um grafico de barras da quantidade de produtos por categoria"
process_question(pergunta)
# Out:
# Query executada com sucesso. Resultados: 5 documentos.
# Query MongoDB Gerada:
#  {
#     'collection': 'produtos',
#     'aggregate': [
#         {
#             '$group': {
#                 '_id': '$categoria',
#                 'total_produtos': { '$sum': '$estoque' }
#             }
#         }
#     ]
# }
#
# Resultados da Query:
# [
#   {
#     "_id": "Alimentos",
#     "total_produtos": 6611
#   },
#   {
#     "_id": "Roupas",
#     "total_produtos": 6927
#   },
#   {
#     "_id": "Eletrônicos",
#     "total_produtos": 7365
#   },
#   {
#     "_id": "Livros",
#     "total_produtos": 7650
#   },
#   {
#     "_id": "Móveis",
#     "total_produtos": 7187
#   }
# ]
#
# Interpretação:
# A quantidade de produtos varia entre as categorias, com 'Livros' apresentando o maior total de 7650 produtos, seguido por 'Eletrônicos' com 7365, 'Móveis' com 7187, 'Roupas' com 6927 e 'Alimentos' com 6611. Isso indica que a categoria de Livros é a mais representativa em termos de quantidade de produtos disponíveis, enquanto Alimentos é a menos representativa.
#         <div class="plot-container">
#             <img src="data:image/png;base64,..."
#                  alt="Gráfico"
#                  style="width:100%; max-width:800px; margin:0 auto; display:block;">
#         </div>

# %%
pergunta = "Calcule os outliers dos preços dos produtos"
process_question(pergunta)
# Out:
# Query executada com sucesso. Resultados: 1 documentos.
# Query MongoDB Gerada:
#  {
#     'collection': 'produtos',
#     'aggregate': [
#         {
#             '$group': {
#                 '_id': None,
#                 'media_preco': { '$avg': '$preco' },
#                 'desvio_padrao': { '$stdDevPop': '$preco' }
#             }
#         },
#         {
#             '$project': {
#                 'limite_inferior': { '$subtract': ['$media_preco', { '$multiply': ['$desvio_padrao', 1.5] }] },
#                 'limite_superior': { '$add': ['$media_preco', { '$multiply': ['$desvio_padrao', 1.5] }] }
#             }
#         },
#         {
#             '$lookup': {
#                 'from': 'produtos',
#                 'let': {
#                     'limite_inferior': '$limite_inferior',
#                     'limite_superior': '$limite_superior'
#                 },
#                 'pipeline': [
#                     {
#                         '$match': {
#                             '$expr': {
#                                 '$or': [
#                                     { '$lt': ['$preco', '$$limite_inferior'] },
#                                     { '$gt': ['$preco', '$$limite_superior'] }
#                                 ]
#                             }
#                         }
#                     }
#                 ],
#                 'as': 'outliers'
#             }
#         }
#     ]
# }
#
# Resultados da Query:
# [
#   {
#     "_id": null,
#     "limite_inferior": 77.34004920215045,
#     "limite_superior": 923.3930650835639,
#     "outliers": [
#       {
#         "_id": "674a8c50d1e62a839cf8a218",
#         "nome": "Modi",
#         "descricao": "Similique atque temporibus velit.",
#         "preco": 19.35,
#         "categoria": "Móveis",
#         "estoque": 31
#       },
#       {
#         "_id": "674a8c50d1e62a839cf8a223",
#         "nome": "Quod",
#         "descricao": "Explicabo quia atque maxime.",
#         "preco": 25.04,
#         "categoria": "Roupas",
#         "estoque": 37
#       },
#       {
#         "_id": "674a8c50d1e62a839cf8a226",
#         "nome": "Expedita",
#         "descricao": "Mollitia rerum illum.",
#         "preco": 46.55,
#         "categoria": "Eletrônicos",
#         "estoque": 25
#       },
#       {
#         "_id": "674a8c50d1e62a839cf8a22a",
#         "nome": "Vel",
#         "descricao": "Necessitatibus eius maxime.",
#         "preco": 18.77,
#         "categoria": "Eletrônicos",
#         "estoque": 8
#       },
#       {
#         "_id": "674a8c50d1e62a839cf8a230",
#         "nome": "Minima",
#         "descricao": "Molestiae ullam harum illum molestiae quas praesentium.",
#         "preco": 940.88,
#         "categoria": "Alimentos",
#         "estoque": 68
#       },
#       {
#         "_id": "674a8c50d1e62a839cf8a236",
#         "nome": "Assumenda",
#         "descricao": "Doloribus deleniti ullam tempore facilis facere beatae ab.",
#         "preco": 35.07,
#         "categoria": "Móveis",
#         "estoque": 30
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a372",
#         "nome": "Numquam",
#         "descricao": "Accusantium repellendus amet libero.",
#         "preco": 49.42,
#         "categoria": "Alimentos",
#         "estoque": 11
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a377",
#         "nome": "Ea",
#         "descricao": "Minima excepturi neque dolorem qui expedita ut doloremque.",
#         "preco": 39.65,
#         "categoria": "Móveis",
#         "estoque": 97
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a381",
#         "nome": "Placeat",
#         "descricao": "Commodi quas architecto deserunt architecto.",
#         "preco": 982.31,
#         "categoria": "Roupas",
#         "estoque": 72
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a392",
#         "nome": "Perspiciatis",
#         "descricao": "Laboriosam tempora minus provident iste.",
#         "preco": 68.69,
#         "categoria": "Móveis",
#         "estoque": 52
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a39b",
#         "nome": "Unde",
#         "descricao": "Modi ratione corrupti sapiente voluptates quasi quidem.",
#         "preco": 36.97,
#         "categoria": "Roupas",
#         "estoque": 5
#       },
#       {
#         "_id": "674a8c96d1e62a839cf8a39e",
#         "nome": "Quaerat",
#         "descricao": "Molestiae culpa cupiditate quos quibusdam quas.",
#         "preco": 935.12,
#         "categoria": "Roupas",
#         "estoque": 22
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9792",
#         "nome": "Nisi",
#         "descricao": "Ratione itaque perspiciatis ullam quos.",
#         "preco": 951.92,
#         "categoria": "Eletrônicos",
#         "estoque": 11,
#         "data_cadastro": "2024-06-26 01:51:27.437000",
#         "fornecedor": "Correia - EI",
#         "avaliacao": 2.1
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa979f",
#         "nome": "Corporis",
#         "descricao": "Nulla et soluta dolore magnam.",
#         "preco": 52.16,
#         "categoria": "Livros",
#         "estoque": 18,
#         "data_cadastro": "2024-10-06 04:37:35.197000",
#         "fornecedor": "Moreira S/A",
#         "avaliacao": 2.3
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97b7",
#         "nome": "Ea",
#         "descricao": "Officia quidem commodi ab in libero.",
#         "preco": 36.83,
#         "categoria": "Móveis",
#         "estoque": 92,
#         "data_cadastro": "2024-09-15 09:28:42.829000",
#         "fornecedor": "Sousa Novais - EI",
#         "avaliacao": 2.1
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97be",
#         "nome": "Dolorum",
#         "descricao": "Corrupti enim doloribus architecto reiciendis vel esse.",
#         "preco": 11.42,
#         "categoria": "Livros",
#         "estoque": 49,
#         "data_cadastro": "2024-01-27 20:33:27.497000",
#         "fornecedor": "Castro - EI",
#         "avaliacao": 1.1
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97c3",
#         "nome": "Recusandae",
#         "descricao": "Optio cupiditate beatae dolorem maxime blanditiis.",
#         "preco": 13.24,
#         "categoria": "Livros",
#         "estoque": 65,
#         "data_cadastro": "2024-10-13 00:56:52.089000",
#         "fornecedor": "da Cruz",
#         "avaliacao": 1.6
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97c7",
#         "nome": "Earum",
#         "descricao": "Rem hic beatae itaque minus dicta.",
#         "preco": 72.31,
#         "categoria": "Roupas",
#         "estoque": 58,
#         "data_cadastro": "2024-03-28 13:02:02.591000",
#         "fornecedor": "da Cunha S/A",
#         "avaliacao": 3.8
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97cf",
#         "nome": "Explicabo",
#         "descricao": "Eaque nam saepe veniam impedit.",
#         "preco": 66.07,
#         "categoria": "Livros",
#         "estoque": 9,
#         "data_cadastro": "2024-02-01 01:09:44.837000",
#         "fornecedor": "Barbosa Pastor Ltda.",
#         "avaliacao": 4.1
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97d1",
#         "nome": "Illum",
#         "descricao": "Ab aperiam fugiat quo sit ratione ipsam.",
#         "preco": 982.13,
#         "categoria": "Móveis",
#         "estoque": 97,
#         "data_cadastro": "2024-03-13 07:17:01.275000",
#         "fornecedor": "Cavalcante",
#         "avaliacao": 3.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97e3",
#         "nome": "Quas",
#         "descricao": "Possimus molestiae similique adipisci.",
#         "preco": 942.66,
#         "categoria": "Livros",
#         "estoque": 3,
#         "data_cadastro": "2024-04-06 08:06:57.585000",
#         "fornecedor": "Cavalcanti",
#         "avaliacao": 2.9
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97e7",
#         "nome": "Corrupti",
#         "descricao": "Aperiam deserunt adipisci reiciendis repudiandae blanditiis autem.",
#         "preco": 949.44,
#         "categoria": "Eletrônicos",
#         "estoque": 33,
#         "data_cadastro": "2024-09-13 10:35:15.758000",
#         "fornecedor": "Novais Silveira e Filhos",
#         "avaliacao": 4.0
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97f0",
#         "nome": "Culpa",
#         "descricao": "Quas ea rem perferendis.",
#         "preco": 30.04,
#         "categoria": "Roupas",
#         "estoque": 17,
#         "data_cadastro": "2024-09-04 10:09:06.380000",
#         "fornecedor": "Pimenta Câmara S.A.",
#         "avaliacao": 2.1
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97f4",
#         "nome": "Nemo",
#         "descricao": "Necessitatibus temporibus quae nulla aliquam eos.",
#         "preco": 940.84,
#         "categoria": "Alimentos",
#         "estoque": 36,
#         "data_cadastro": "2024-05-21 23:52:53.340000",
#         "fornecedor": "da Costa Nascimento Ltda.",
#         "avaliacao": 4.5
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97f7",
#         "nome": "Rem",
#         "descricao": "Omnis pariatur eius quidem.",
#         "preco": 997.78,
#         "categoria": "Eletrônicos",
#         "estoque": 84,
#         "data_cadastro": "2024-04-09 23:26:10.246000",
#         "fornecedor": "Azevedo",
#         "avaliacao": 2.6
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa97f8",
#         "nome": "Facere",
#         "descricao": "Distinctio possimus voluptas accusantium aperiam fugit.",
#         "preco": 46.98,
#         "categoria": "Eletrônicos",
#         "estoque": 2,
#         "data_cadastro": "2024-02-01 17:32:12.192000",
#         "fornecedor": "Correia S/A",
#         "avaliacao": 2.0
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9801",
#         "nome": "Est",
#         "descricao": "Et est numquam rem deserunt quod sed.",
#         "preco": 15.79,
#         "categoria": "Alimentos",
#         "estoque": 5,
#         "data_cadastro": "2024-03-10 08:51:40.902000",
#         "fornecedor": "Macedo da Rosa S/A",
#         "avaliacao": 2.8
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa980a",
#         "nome": "Quibusdam",
#         "descricao": "Exercitationem corporis explicabo aperiam ducimus blanditiis amet.",
#         "preco": 70.76,
#         "categoria": "Eletrônicos",
#         "estoque": 93,
#         "data_cadastro": "2024-06-04 14:39:43.685000",
#         "fornecedor": "Casa Grande Gonçalves S.A.",
#         "avaliacao": 1.5
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9816",
#         "nome": "Molestiae",
#         "descricao": "Quae vitae rerum corrupti nulla vitae.",
#         "preco": 25.63,
#         "categoria": "Eletrônicos",
#         "estoque": 28,
#         "data_cadastro": "2024-07-31 01:28:04.798000",
#         "fornecedor": "Siqueira S/A",
#         "avaliacao": 4.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9817",
#         "nome": "Ipsam",
#         "descricao": "Voluptate est accusamus.",
#         "preco": 956.79,
#         "categoria": "Alimentos",
#         "estoque": 82,
#         "data_cadastro": "2024-07-10 20:19:53.268000",
#         "fornecedor": "Moura Oliveira S.A.",
#         "avaliacao": 1.6
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9821",
#         "nome": "Ipsum",
#         "descricao": "Ab repellat a ullam.",
#         "preco": 982.96,
#         "categoria": "Livros",
#         "estoque": 15,
#         "data_cadastro": "2024-01-15 06:50:42.884000",
#         "fornecedor": "Farias Ramos S.A.",
#         "avaliacao": 1.9
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9822",
#         "nome": "Nisi",
#         "descricao": "Porro magnam incidunt eligendi rerum.",
#         "preco": 21.19,
#         "categoria": "Eletrônicos",
#         "estoque": 36,
#         "data_cadastro": "2024-03-21 22:04:50.626000",
#         "fornecedor": "Ferreira",
#         "avaliacao": 3.4
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa982b",
#         "nome": "Fugit",
#         "descricao": "Itaque eius natus quasi quaerat.",
#         "preco": 926.84,
#         "categoria": "Móveis",
#         "estoque": 85,
#         "data_cadastro": "2023-12-21 14:19:10.634000",
#         "fornecedor": "Cardoso - EI",
#         "avaliacao": 3.5
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9836",
#         "nome": "Consequuntur",
#         "descricao": "Iste aut quos nihil rerum.",
#         "preco": 943.49,
#         "categoria": "Livros",
#         "estoque": 26,
#         "data_cadastro": "2024-05-20 09:04:00.388000",
#         "fornecedor": "Farias - ME",
#         "avaliacao": 3.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa983e",
#         "nome": "Doloribus",
#         "descricao": "Accusantium praesentium natus nihil corrupti.",
#         "preco": 923.89,
#         "categoria": "Eletrônicos",
#         "estoque": 43,
#         "data_cadastro": "2024-06-07 17:50:12.526000",
#         "fornecedor": "Gomes",
#         "avaliacao": 4.3
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9843",
#         "nome": "Voluptatem",
#         "descricao": "Saepe aliquid doloribus molestiae nostrum.",
#         "preco": 51.95,
#         "categoria": "Móveis",
#         "estoque": 36,
#         "data_cadastro": "2023-12-24 17:21:27.358000",
#         "fornecedor": "Duarte - ME",
#         "avaliacao": 1.6
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa984d",
#         "nome": "Fugit",
#         "descricao": "Doloribus doloremque cumque quae iste consequatur.",
#         "preco": 940.2,
#         "categoria": "Móveis",
#         "estoque": 85,
#         "data_cadastro": "2024-09-16 16:38:08.089000",
#         "fornecedor": "Albuquerque da Cunha Ltda.",
#         "avaliacao": 1.9
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa984e",
#         "nome": "Amet",
#         "descricao": "Officiis pariatur deserunt magni ipsum nisi nobis.",
#         "preco": 999.52,
#         "categoria": "Móveis",
#         "estoque": 29,
#         "data_cadastro": "2024-08-26 13:02:08.445000",
#         "fornecedor": "Gonçalves",
#         "avaliacao": 4.2
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9850",
#         "nome": "Molestiae",
#         "descricao": "Tempora ipsam laudantium nemo.",
#         "preco": 963.13,
#         "categoria": "Livros",
#         "estoque": 75,
#         "data_cadastro": "2024-06-01 14:21:06.500000",
#         "fornecedor": "da Luz S/A",
#         "avaliacao": 1.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9853",
#         "nome": "Asperiores",
#         "descricao": "Impedit non quae possimus.",
#         "preco": 939.95,
#         "categoria": "Roupas",
#         "estoque": 85,
#         "data_cadastro": "2024-04-28 08:43:05.024000",
#         "fornecedor": "Fonseca",
#         "avaliacao": 4.9
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa985e",
#         "nome": "Nihil",
#         "descricao": "At reiciendis sint rem quo.",
#         "preco": 972.59,
#         "categoria": "Eletrônicos",
#         "estoque": 30,
#         "data_cadastro": "2024-02-06 10:46:37.762000",
#         "fornecedor": "Caldeira",
#         "avaliacao": 2.9
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa986a",
#         "nome": "Quia",
#         "descricao": "Et occaecati expedita totam voluptates quaerat.",
#         "preco": 927.73,
#         "categoria": "Alimentos",
#         "estoque": 1,
#         "data_cadastro": "2024-08-02 22:20:57.082000",
#         "fornecedor": "Rocha e Filhos",
#         "avaliacao": 1.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa986d",
#         "nome": "Repellendus",
#         "descricao": "Vitae corrupti totam sit.",
#         "preco": 73.31,
#         "categoria": "Roupas",
#         "estoque": 47,
#         "data_cadastro": "2024-09-04 19:15:54.285000",
#         "fornecedor": "Campos",
#         "avaliacao": 3.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9870",
#         "nome": "Distinctio",
#         "descricao": "Magnam ducimus dolorem itaque.",
#         "preco": 981.02,
#         "categoria": "Eletrônicos",
#         "estoque": 15,
#         "data_cadastro": "2024-10-27 05:16:46.690000",
#         "fornecedor": "Câmara",
#         "avaliacao": 1.8
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9872",
#         "nome": "Itaque",
#         "descricao": "Minima necessitatibus delectus iure nihil necessitatibus distinctio minus.",
#         "preco": 974.22,
#         "categoria": "Móveis",
#         "estoque": 6,
#         "data_cadastro": "2023-12-25 16:09:53.811000",
#         "fornecedor": "Melo",
#         "avaliacao": 2.7
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9878",
#         "nome": "Tempore",
#         "descricao": "Molestias modi ut voluptate fugiat aliquid officiis.",
#         "preco": 37.43,
#         "categoria": "Eletrônicos",
#         "estoque": 66,
#         "data_cadastro": "2023-12-02 14:09:35.687000",
#         "fornecedor": "Pimenta S/A",
#         "avaliacao": 1.3
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa987b",
#         "nome": "Maiores",
#         "descricao": "Quia mollitia ab magnam nihil labore.",
#         "preco": 974.35,
#         "categoria": "Livros",
#         "estoque": 19,
#         "data_cadastro": "2024-06-13 00:17:54.919000",
#         "fornecedor": "Abreu - EI",
#         "avaliacao": 4.5
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9880",
#         "nome": "Molestias",
#         "descricao": "Vitae autem ab quibusdam.",
#         "preco": 942.59,
#         "categoria": "Móveis",
#         "estoque": 28,
#         "data_cadastro": "2024-09-12 18:35:23.469000",
#         "fornecedor": "Lima",
#         "avaliacao": 2.4
#       },
#       {
#         "_id": "674b4b3801d4422b9aaa9882",
#         "nome": "Quam",
#         "descricao": "Soluta magnam eius voluptatem necessitatibus eum aliquam.",
#         "preco": 936.29,
#         "categoria": "Móveis",
#         "estoque": 66,
#         "data_cadastro": "2024-07-25 15:22:04.466000",
#         "fornecedor": "Rezende",
#         "avaliacao": 3.2
#       },
#       {
#         "_id": "674ceb11eeb3778b09a14566",
#         "nome": "Repellat",
#         "descricao": "In libero quisquam excepturi dicta esse.",
#         "preco": 45.86,
#         "categoria": "Móveis",
#         "estoque": 30
#       },
#       {
#         "_id": "674ceb11eeb3778b09a14567",
#         "nome": "Adipisci",
#         "descricao": "Temporibus deserunt magni recusandae.",
#         "preco": 983.22,
#         "categoria": "Livros",
#         "estoque": 63
#       },
#       {
#         "_id": "674ceb11eeb3778b09a1456b",
#         "nome": "Velit",
#         "descricao": "Voluptates perspiciatis placeat tempora.",
#         "preco": 935.72,
#         "categoria": "Alimentos",
#         "estoque": 91
#       },
#       {
#         "_id": "674ceb11eeb3778b09a14584",
#         "nome": "Reiciendis",
#         "descricao": "Quia accusamus in iusto inventore voluptate labore.",
#         "preco": 12.17,
#         "categoria": "Alimentos",
#         "estoque": 8
#       },
#       {
#         "_id": "674ceb11eeb3778b09a14593",
#         "nome": "Neque",
#         "descricao": "Harum voluptas voluptate asperiores molestias.",
#         "preco": 960.14,
#         "categoria": "Livros",
#         "estoque": 54
#       },
#       {
#         "_id": "674ceb11eeb3778b09a14594",
#         "nome": "Voluptate",
#         "descricao": "Earum doloremque recusandae totam laborum veritatis deleniti.",
#         "preco": 29.36,
#         "categoria": "Livros",
#         "estoque": 20
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14728",
#         "nome": "Quia",
#         "descricao": "Blanditiis quos quia eius illum ipsam.",
#         "preco": 931.09,
#         "categoria": "Móveis",
#         "estoque": 35
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1472e",
#         "nome": "Voluptate",
#         "descricao": "Nobis voluptatibus alias deserunt.",
#         "preco": 74.05,
#         "categoria": "Eletrônicos",
#         "estoque": 30
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1472f",
#         "nome": "Autem",
#         "descricao": "Earum iusto dolor ullam rem neque.",
#         "preco": 955.58,
#         "categoria": "Alimentos",
#         "estoque": 98
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14731",
#         "nome": "Ut",
#         "descricao": "Eaque tenetur veritatis totam quae corrupti.",
#         "preco": 954.03,
#         "categoria": "Livros",
#         "estoque": 65
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14733",
#         "nome": "Modi",
#         "descricao": "Mollitia sint laudantium laboriosam.",
#         "preco": 947.11,
#         "categoria": "Móveis",
#         "estoque": 68
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14738",
#         "nome": "Eius",
#         "descricao": "Temporibus eligendi culpa alias quasi quia.",
#         "preco": 60.89,
#         "categoria": "Roupas",
#         "estoque": 96
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1473b",
#         "nome": "Natus",
#         "descricao": "Sequi nostrum omnis ratione iure unde est.",
#         "preco": 973.46,
#         "categoria": "Roupas",
#         "estoque": 11
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1473c",
#         "nome": "Maiores",
#         "descricao": "Impedit aperiam asperiores eligendi eligendi.",
#         "preco": 10.24,
#         "categoria": "Livros",
#         "estoque": 97
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1474b",
#         "nome": "Explicabo",
#         "descricao": "In ducimus exercitationem repellat iste harum.",
#         "preco": 22.68,
#         "categoria": "Livros",
#         "estoque": 37
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1474d",
#         "nome": "Eius",
#         "descricao": "Unde alias dolor autem laboriosam.",
#         "preco": 992.03,
#         "categoria": "Alimentos",
#         "estoque": 37
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14751",
#         "nome": "Ipsa",
#         "descricao": "Exercitationem accusantium sint repudiandae.",
#         "preco": 963.22,
#         "categoria": "Móveis",
#         "estoque": 99
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14759",
#         "nome": "Provident",
#         "descricao": "Perferendis adipisci et iste aliquam officiis deleniti.",
#         "preco": 23.6,
#         "categoria": "Livros",
#         "estoque": 35
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14762",
#         "nome": "Delectus",
#         "descricao": "Voluptatem nam porro nihil rerum nemo.",
#         "preco": 32.6,
#         "categoria": "Eletrônicos",
#         "estoque": 35
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14764",
#         "nome": "Repellat",
#         "descricao": "Quisquam autem perspiciatis ea nemo.",
#         "preco": 942.0,
#         "categoria": "Móveis",
#         "estoque": 85
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14766",
#         "nome": "Iure",
#         "descricao": "Blanditiis dolores reiciendis non iure molestias necessitatibus.",
#         "preco": 16.23,
#         "categoria": "Alimentos",
#         "estoque": 28
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14779",
#         "nome": "Laborum",
#         "descricao": "Animi molestias odio nobis iste ullam aliquid.",
#         "preco": 943.83,
#         "categoria": "Alimentos",
#         "estoque": 61
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1477c",
#         "nome": "Aspernatur",
#         "descricao": "Fuga sit in inventore temporibus.",
#         "preco": 966.03,
#         "categoria": "Móveis",
#         "estoque": 10
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1477e",
#         "nome": "Molestiae",
#         "descricao": "Mollitia pariatur quas totam fugiat.",
#         "preco": 972.5,
#         "categoria": "Móveis",
#         "estoque": 12
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a14795",
#         "nome": "Qui",
#         "descricao": "Harum labore adipisci.",
#         "preco": 945.54,
#         "categoria": "Eletrônicos",
#         "estoque": 24
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a1479f",
#         "nome": "Totam",
#         "descricao": "Minima quia dolores expedita.",
#         "preco": 27.19,
#         "categoria": "Alimentos",
#         "estoque": 62
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a147a8",
#         "nome": "Excepturi",
#         "descricao": "Commodi a reiciendis maiores dolorem assumenda quaerat.",
#         "preco": 27.96,
#         "categoria": "Móveis",
#         "estoque": 87
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a147af",
#         "nome": "Molestias",
#         "descricao": "Eos distinctio minus eveniet tempore.",
#         "preco": 996.89,
#         "categoria": "Alimentos",
#         "estoque": 86
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a147b6",
#         "nome": "Porro",
#         "descricao": "At beatae reprehenderit laudantium molestiae asperiores.",
#         "preco": 76.07,
#         "categoria": "Livros",
#         "estoque": 26
#       },
#       {
#         "_id": "674cf3dbeeb3778b09a147b9",
#         "nome": "Voluptate",
#         "descricao": "Tempore possimus eveniet deserunt nemo.",
#         "preco": 42.09,
#         "categoria": "Alimentos",
#         "estoque": 23
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14923",
#         "nome": "Facilis",
#         "descricao": "Sint eum magnam debitis quam consectetur.",
#         "preco": 966.01,
#         "categoria": "Eletrônicos",
#         "estoque": 92
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14929",
#         "nome": "Laboriosam",
#         "descricao": "Velit in fugit dolorem cupiditate eum.",
#         "preco": 53.93,
#         "categoria": "Alimentos",
#         "estoque": 31
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a1492b",
#         "nome": "Deserunt",
#         "descricao": "Labore earum sit eaque non nihil soluta.",
#         "preco": 20.79,
#         "categoria": "Alimentos",
#         "estoque": 27
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a1492e",
#         "nome": "Officia",
#         "descricao": "Fugiat corrupti corporis ullam.",
#         "preco": 970.02,
#         "categoria": "Eletrônicos",
#         "estoque": 7
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14938",
#         "nome": "Libero",
#         "descricao": "Sed tempora cum nostrum voluptatem ex.",
#         "preco": 66.65,
#         "categoria": "Móveis",
#         "estoque": 95
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14941",
#         "nome": "Aut",
#         "descricao": "Voluptatem blanditiis provident ipsa voluptates nobis.",
#         "preco": 998.88,
#         "categoria": "Eletrônicos",
#         "estoque": 73
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14944",
#         "nome": "Consequatur",
#         "descricao": "Voluptatem aut ipsa libero expedita.",
#         "preco": 70.7,
#         "categoria": "Eletrônicos",
#         "estoque": 13
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14946",
#         "nome": "Quia",
#         "descricao": "Laboriosam temporibus ab atque sed fuga saepe.",
#         "preco": 958.52,
#         "categoria": "Livros",
#         "estoque": 42
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14954",
#         "nome": "Provident",
#         "descricao": "Facilis iste reiciendis perspiciatis enim modi asperiores laboriosam.",
#         "preco": 32.09,
#         "categoria": "Móveis",
#         "estoque": 66
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14956",
#         "nome": "Facilis",
#         "descricao": "Optio fugiat nostrum repellendus unde id aut.",
#         "preco": 25.19,
#         "categoria": "Livros",
#         "estoque": 83
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14957",
#         "nome": "Tempore",
#         "descricao": "Hic repellat temporibus iusto molestias magni doloremque voluptatibus.",
#         "preco": 995.75,
#         "categoria": "Eletrônicos",
#         "estoque": 46
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14961",
#         "nome": "Facere",
#         "descricao": "Assumenda quidem harum.",
#         "preco": 30.19,
#         "categoria": "Roupas",
#         "estoque": 52
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14963",
#         "nome": "Ipsa",
#         "descricao": "Iusto molestiae porro facere rem aliquid.",
#         "preco": 56.18,
#         "categoria": "Livros",
#         "estoque": 98
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14977",
#         "nome": "Quia",
#         "descricao": "Voluptate vero ratione nam quo incidunt.",
#         "preco": 948.32,
#         "categoria": "Livros",
#         "estoque": 66
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a1498e",
#         "nome": "Nulla",
#         "descricao": "Exercitationem esse ipsa voluptatibus exercitationem consectetur officia.",
#         "preco": 23.54,
#         "categoria": "Livros",
#         "estoque": 86
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14990",
#         "nome": "Repudiandae",
#         "descricao": "Quibusdam perferendis corporis eum.",
#         "preco": 27.61,
#         "categoria": "Móveis",
#         "estoque": 27
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a14998",
#         "nome": "Velit",
#         "descricao": "Eveniet aliquam sed eius voluptates illo deserunt.",
#         "preco": 945.6,
#         "categoria": "Livros",
#         "estoque": 100
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a1499a",
#         "nome": "Eius",
#         "descricao": "Accusantium eos sequi ad in ea.",
#         "preco": 14.5,
#         "categoria": "Roupas",
#         "estoque": 33
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a149a3",
#         "nome": "Laboriosam",
#         "descricao": "Quas tempora asperiores eius necessitatibus.",
#         "preco": 986.85,
#         "categoria": "Livros",
#         "estoque": 92
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a149ab",
#         "nome": "Sed",
#         "descricao": "Consectetur ipsum possimus esse aliquam illo ullam.",
#         "preco": 28.06,
#         "categoria": "Eletrônicos",
#         "estoque": 46
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a149ad",
#         "nome": "Sit",
#         "descricao": "Perferendis blanditiis culpa assumenda laborum voluptates consectetur.",
#         "preco": 991.94,
#         "categoria": "Móveis",
#         "estoque": 90
#       },
#       {
#         "_id": "674cf3f9eeb3778b09a149b1",
#         "nome": "Tenetur",
#         "descricao": "Culpa dignissimos adipisci ullam voluptate.",
#         "preco": 65.91,
#         "categoria": "Roupas",
#         "estoque": 46
#       }
#     ]
#   }
# ]
#
# Interpretação:
# Os resultados mostram que os preços dos produtos têm um limite inferior de aproximadamente 77,34 e um limite superior de cerca de 923,39. Os outliers identificados são produtos com preços significativamente abaixo do limite inferior ou acima do limite superior. Entre os outliers, há produtos com preços que variam de 11,42 a 997,78, indicando que existem produtos com preços muito baixos e muito altos em relação à média do conjunto. Isso pode sugerir uma grande variação nos preços dos produtos, possivelmente devido a diferentes categorias ou características.
# Nenhum gráfico gerado.

# %%
pergunta = "Faca  um grafico comparando o preco dos 3 produtos mais caros"
process_question(pergunta)
# Out:
# Query executada com sucesso. Resultados: 3 documentos.
# Query MongoDB Gerada:
#  {
#     'collection': 'produtos',
#     'aggregate': [
#         {
#             '$sort': {
#                 'preco': -1
#             }
#         },
#         {
#             '$limit': 3
#         },
#         {
#             '$project': {
#                 'nome': 1,
#                 'preco': 1
#             }
#         }
#     ]
# }
#
# Resultados da Query:
# [
#   {
#     "_id": "674b4b3801d4422b9aaa984e",
#     "nome": "Amet",
#     "preco": 999.52
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14941",
#     "nome": "Aut",
#     "preco": 998.88
#   },
#   {
#     "_id": "674b4b3801d4422b9aaa97f7",
#     "nome": "Rem",
#     "preco": 997.78
#   }
# ]
#
# Interpretação:
# Os três produtos mais caros são 'Amet' com preço de 999.52, 'Aut' com preço de 998.88 e 'Rem' com preço de 997.78. A diferença de preços entre eles é muito pequena, com 'Amet' sendo o mais caro, seguido por 'Aut' e 'Rem'.
#         <div class="plot-container">
#             <img src="data:image/png;base64,..."
#                  alt="Gráfico"
#                  style="width:100%; max-width:800px; margin:0 auto; display:block;">
#         </div>

# %%
pergunta = "Quais as 5 primeiras linhas da colecao clientes?"
process_question(pergunta)
# Out:
# Query executada com sucesso. Resultados: 1200 documentos.
# Nenhum valor numérico encontrado para plotagem.
# Query MongoDB Gerada:
#  {
#     'collection': 'clientes',
#     'find': {},
#     'limit': 5
# }
#
# Resultados da Query:
# [
#   {
#     "_id": "674a8c50d1e62a839cf8a1aa",
#     "nome": "Olivia da Cruz",
#     "email": "ecamara@example.com",
#     "endereco": "Praça Machado, 53\nAraguaia\n49830712 Melo da Mata / RO",
#     "telefone": "+55 (011) 2116-1910"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ab",
#     "nome": "Lívia Gomes",
#     "email": "limaluana@example.org",
#     "endereco": "Área de Sá, 21\nBandeirantes\n82336000 Castro de Andrade / RN",
#     "telefone": "51 9740 1897"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ac",
#     "nome": "Srta. Maria Alice Montenegro",
#     "email": "eloahlima@example.net",
#     "endereco": "Ladeira Mendes, 88\nPiratininga\n46082-907 Silva / SP",
#     "telefone": "+55 81 2789-6543"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ad",
#     "nome": "Aylla Gonçalves",
#     "email": "thales04@example.net",
#     "endereco": "Vila de Lima, 43\nVila Mangueiras\n93905548 Nunes / RO",
#     "telefone": "31 7059-2162"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ae",
#     "nome": "Sophie Novaes",
#     "email": "marianecasa-grande@example.org",
#     "endereco": "Trevo de Castro, 98\nNovo Ouro Preto\n94112010 Viana / CE",
#     "telefone": "0300 868 4934"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1af",
#     "nome": "Emilly Leão",
#     "email": "meloevelyn@example.net",
#     "endereco": "Lago Enrico Cavalcante, 24\nLorena\n75605-605 da Cruz / RN",
#     "telefone": "+55 21 5010-4004"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b0",
#     "nome": "Erick Pastor",
#     "email": "ribeirosophie@example.com",
#     "endereco": "Estação de Alves\nVila Santa Monica 2ª Seção\n70298-121 da Cruz / GO",
#     "telefone": "+55 (061) 9254 5903"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b1",
#     "nome": "Jade Moreira",
#     "email": "ana-sophia98@example.org",
#     "endereco": "Campo de da Cunha, 3\nVila Paris\n44304-215 Costa / TO",
#     "telefone": "+55 51 8640 0125"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b2",
#     "nome": "Arthur Gabriel Sales",
#     "email": "oda-luz@example.com",
#     "endereco": "Loteamento Silveira, 880\nGraça\n18455670 Martins do Campo / TO",
#     "telefone": "0800 344 3920"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b3",
#     "nome": "Thiago Aragão",
#     "email": "maria-lizfonseca@example.com",
#     "endereco": "Trevo Castro\nConjunto Taquaril\n01534-582 Silveira das Flores / SC",
#     "telefone": "+55 (084) 9842 1420"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b4",
#     "nome": "Nina Abreu",
#     "email": "dante69@example.org",
#     "endereco": "Via Carlos Eduardo Viana, 88\nVila Nova\n21393-544 Farias dos Dourados / RS",
#     "telefone": "+55 (081) 9543 9606"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b5",
#     "nome": "Gustavo Henrique da Paz",
#     "email": "ana-cecilia21@example.net",
#     "endereco": "Condomínio Cunha, 52\nMariano De Abreu\n27355-709 Cassiano Grande / SE",
#     "telefone": "+55 (031) 3340-7762"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b6",
#     "nome": "Eloah Pinto",
#     "email": "ana-luizaborges@example.com",
#     "endereco": "Loteamento de Pimenta, 49\nDona Clara\n88726766 Fonseca / RJ",
#     "telefone": "41 4540-7762"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b7",
#     "nome": "Rael Santos",
#     "email": "maria-clarada-mata@example.org",
#     "endereco": "Rua de Gomes, 6\nVila Suzana Segunda Seção\n00859106 Souza / AP",
#     "telefone": "+55 (061) 8246 8038"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b8",
#     "nome": "Ana Carolina Vieira",
#     "email": "franciscocostela@example.com",
#     "endereco": "Feira de Cavalcanti, 359\nVila Betânia\n47765559 Casa Grande / RJ",
#     "telefone": "(011) 1151-9784"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1b9",
#     "nome": "Oliver da Rocha",
#     "email": "paulo95@example.com",
#     "endereco": "Loteamento de Martins, 984\nErnesto Nascimento\n47251972 Campos Verde / DF",
#     "telefone": "+55 (031) 3065 1320"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ba",
#     "nome": "Sra. Giovanna Rios",
#     "email": "hellena48@example.org",
#     "endereco": "Morro de Garcia, 98\nConjunto Providencia\n40337860 Campos de Casa Grande / DF",
#     "telefone": "+55 21 9338-4708"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1bb",
#     "nome": "Juliana Caldeira",
#     "email": "caldeiragustavo@example.com",
#     "endereco": "Setor Vargas, 599\nAraguaia\n00158-554 Souza da Mata / RJ",
#     "telefone": "+55 (051) 9809-9792"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1bc",
#     "nome": "Henry Gabriel Mendonça",
#     "email": "maria-liz18@example.org",
#     "endereco": "Favela Ana Luiza da Costa, 76\nVila Trinta E Um De Março\n74202-781 Melo / AC",
#     "telefone": "+55 (084) 3690 9055"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1bd",
#     "nome": "João Felipe Câmara",
#     "email": "davi-luizporto@example.com",
#     "endereco": "Morro Fonseca, 82\nProvidencia\n85873-690 Pereira / TO",
#     "telefone": "71 7054 3944"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1be",
#     "nome": "Matheus Novaes",
#     "email": "diogo12@example.com",
#     "endereco": "Praça de Ferreira, 9\nParque São Pedro\n75763-463 Silva do Sul / RN",
#     "telefone": "(081) 8690-1941"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1bf",
#     "nome": "Clara Silveira",
#     "email": "pimentaana-beatriz@example.org",
#     "endereco": "Rodovia de Martins, 588\nMilionario\n78296153 da Rocha da Praia / BA",
#     "telefone": "+55 (031) 6138-5253"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c0",
#     "nome": "Manuela Abreu",
#     "email": "allanapimenta@example.com",
#     "endereco": "Ladeira Borges, 1\nSão Gonçalo\n07072667 Andrade do Amparo / RR",
#     "telefone": "+55 21 1171 3027"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c1",
#     "nome": "Cecilia Silveira",
#     "email": "marcela60@example.org",
#     "endereco": "Aeroporto Vitor Gabriel da Mata\nBraúnas\n89644-159 Fonseca / MA",
#     "telefone": "84 9006-9398"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c2",
#     "nome": "Marcela da Mota",
#     "email": "vianabento@example.com",
#     "endereco": "Viela Sales, 4\nSão Geraldo\n50252-469 Sales da Serra / AL",
#     "telefone": "11 5978 9650"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c3",
#     "nome": "Benício Borges",
#     "email": "da-luzheitor@example.org",
#     "endereco": "Vale Melina Sampaio\nGuarani\n47249-570 Cirino do Galho / PE",
#     "telefone": "+55 (031) 6716-6680"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c4",
#     "nome": "Asafe Oliveira",
#     "email": "luiz-fernando17@example.net",
#     "endereco": "Aeroporto de da Cunha, 1\nAnchieta\n40554823 Ramos / RJ",
#     "telefone": "71 3332-6655"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c5",
#     "nome": "Gustavo Henrique Aragão",
#     "email": "ebrito@example.org",
#     "endereco": "Feira de Garcia, 88\nSão Tomaz\n12710-112 Câmara / PA",
#     "telefone": "41 9439-4471"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c6",
#     "nome": "Otávio Sales",
#     "email": "sda-mota@example.org",
#     "endereco": "Loteamento Siqueira, 510\nMangabeiras\n96351-087 Ferreira / SC",
#     "telefone": "51 4786 7434"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c7",
#     "nome": "Eloá Monteiro",
#     "email": "nicolas61@example.net",
#     "endereco": "Pátio de Borges, 8\nBelvedere\n34214681 da Mota / TO",
#     "telefone": "+55 (011) 0725-9192"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c8",
#     "nome": "Ísis da Conceição",
#     "email": "goncalvesbella@example.net",
#     "endereco": "Rodovia Anna Liz Leão, 5\nCruzeiro\n90859256 Alves / RJ",
#     "telefone": "(071) 2842-4305"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1c9",
#     "nome": "Gabriela Fonseca",
#     "email": "isaquemacedo@example.net",
#     "endereco": "Feira de Fernandes, 32\nBarão Homem De Melo 2ª Seção\n32469-590 Ramos / TO",
#     "telefone": "(021) 3807-4501"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ca",
#     "nome": "Mateus Sousa",
#     "email": "kjesus@example.com",
#     "endereco": "Vila Jesus, 52\nBernadete\n74393174 Nogueira do Sul / MT",
#     "telefone": "(031) 3583-2518"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1cb",
#     "nome": "Mateus Jesus",
#     "email": "carolina92@example.org",
#     "endereco": "Distrito Bruna Moreira, 34\nTrevo\n29049537 Novais da Serra / RO",
#     "telefone": "+55 41 4765-9292"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1cc",
#     "nome": "Isis Rezende",
#     "email": "arthur60@example.com",
#     "endereco": "Avenida Bento Aragão, 327\nMaria Helena\n23602-377 Silva Paulista / MA",
#     "telefone": "(084) 5930-0337"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1cd",
#     "nome": "Bianca Costa",
#     "email": "ericknovaes@example.com",
#     "endereco": "Colônia de da Conceição, 7\nSão José\n36007-762 Gomes / AC",
#     "telefone": "+55 51 1857 9988"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ce",
#     "nome": "Isabel Rodrigues",
#     "email": "gabrielaaraujo@example.com",
#     "endereco": "Praia Guerra, 9\nBarão Homem De Melo 2ª Seção\n81112-294 Campos Paulista / AL",
#     "telefone": "+55 (081) 2066 1097"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1cf",
#     "nome": "Gabriel Câmara",
#     "email": "juliasilva@example.org",
#     "endereco": "Distrito de Pastor, 7\nLagoinha Leblon\n19825972 Cavalcante Grande / AP",
#     "telefone": "+55 (051) 6636 9409"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d0",
#     "nome": "Bianca Andrade",
#     "email": "wmontenegro@example.org",
#     "endereco": "Residencial de da Mota, 56\nVila São Gabriel\n58837-171 Barros / CE",
#     "telefone": "(011) 9178 6159"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d1",
#     "nome": "Pedro Miguel Rodrigues",
#     "email": "mendesmatheus@example.org",
#     "endereco": "Fazenda Montenegro, 82\nGranja Werneck\n07944686 Moreira / RR",
#     "telefone": "84 1818 2555"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d2",
#     "nome": "João Lucas Cassiano",
#     "email": "joao-gabriel93@example.net",
#     "endereco": "Trevo Maria Alice Freitas, 81\nAarão Reis\n67817396 Pacheco / RN",
#     "telefone": "+55 21 6723 1713"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d3",
#     "nome": "João Pedro Nascimento",
#     "email": "gbrito@example.org",
#     "endereco": "Setor Andrade, 724\nVila Jardim São José\n90752935 Porto / PR",
#     "telefone": "0800-883-5916"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d4",
#     "nome": "Emilly Cavalcante",
#     "email": "theoda-conceicao@example.org",
#     "endereco": "Largo de Câmara, 704\nEsperança\n84723-669 Costa / RS",
#     "telefone": "0500-233-1936"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d5",
#     "nome": "Marcos Vinicius Sampaio",
#     "email": "cavalcantiotto@example.net",
#     "endereco": "Estrada Enrico Freitas, 94\nVila Santo Antônio\n08091-837 Martins Paulista / SP",
#     "telefone": "51 9612 7428"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d6",
#     "nome": "Ravi Lucca Fernandes",
#     "email": "leaojose@example.org",
#     "endereco": "Setor Rezende, 74\nJardim América\n16693433 Duarte de Goiás / AC",
#     "telefone": "(071) 8931 3939"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d7",
#     "nome": "Srta. Ísis da Luz",
#     "email": "pviana@example.net",
#     "endereco": "Campo Nicolas Pacheco, 54\nTúnel De Ibirité\n72745-879 da Mata / ES",
#     "telefone": "(011) 0719-0112"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d8",
#     "nome": "Lívia da Conceição",
#     "email": "ebarros@example.com",
#     "endereco": "Avenida de Porto, 496\nConjunto Floramar\n44641-911 Peixoto / RJ",
#     "telefone": "+55 (031) 5820 9653"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1d9",
#     "nome": "Natália Casa Grande",
#     "email": "anthony-gabrielmoreira@example.org",
#     "endereco": "Praia Pietro Macedo, 52\nSanta Branca\n43793031 Mendonça / GO",
#     "telefone": "(081) 3737 6423"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1da",
#     "nome": "Eloá Costa",
#     "email": "ribeirocaue@example.org",
#     "endereco": "Praça Cunha, 44\nFlamengo\n50119-172 Fonseca Alegre / BA",
#     "telefone": "41 6354-0927"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1db",
#     "nome": "Julia Garcia",
#     "email": "pietrorezende@example.com",
#     "endereco": "Rua de Oliveira, 1\nMaravilha\n39907312 Nunes da Praia / RR",
#     "telefone": "(021) 2948 0836"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1dc",
#     "nome": "Dante Pastor",
#     "email": "lorena08@example.com",
#     "endereco": "Morro Casa Grande\nCabana Do Pai Tomás\n47213-759 da Luz / RS",
#     "telefone": "81 7078-7975"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1dd",
#     "nome": "Manuela Nunes",
#     "email": "baparecida@example.org",
#     "endereco": "Trecho Otto Rezende, 9\nNova Esperança\n67137-086 da Paz / ES",
#     "telefone": "0900 238 3831"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1de",
#     "nome": "Lucca Martins",
#     "email": "isabellapacheco@example.com",
#     "endereco": "Avenida de Montenegro, 8\nCarlos Prates\n17663-164 Almeida de Minas / RJ",
#     "telefone": "+55 (051) 4672-0301"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1df",
#     "nome": "Joaquim Montenegro",
#     "email": "elisa00@example.org",
#     "endereco": "Chácara de Lopes, 76\nJardim Dos Comerciarios\n71450-195 Sá / PI",
#     "telefone": "+55 (051) 5652-0880"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e0",
#     "nome": "Maria Gonçalves",
#     "email": "leo08@example.com",
#     "endereco": "Condomínio Alana Castro, 5\nConjunto Minas Caixa\n90995754 Almeida Alegre / RN",
#     "telefone": "31 4191-2697"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e1",
#     "nome": "Pedro Lucas Vieira",
#     "email": "epeixoto@example.com",
#     "endereco": "Largo Costela, 836\nNova America\n34999-359 Siqueira / RR",
#     "telefone": "(084) 8182-3478"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e2",
#     "nome": "Mariane Pereira",
#     "email": "vabreu@example.org",
#     "endereco": "Passarela Duarte, 62\nSion\n04530369 Pastor de Minas / PA",
#     "telefone": "(021) 0621 3658"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e3",
#     "nome": "Dr. Antony Moraes",
#     "email": "pintopedro@example.com",
#     "endereco": "Vale da Conceição, 15\nVila Pinho\n45001-176 Teixeira / PE",
#     "telefone": "+55 (021) 9867-8584"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e4",
#     "nome": "Milena Melo",
#     "email": "heitor14@example.org",
#     "endereco": "Loteamento Santos, 75\nBoa Esperança\n12560-971 das Neves / BA",
#     "telefone": "+55 (061) 3681-3150"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e5",
#     "nome": "Lorena da Cunha",
#     "email": "hda-mata@example.net",
#     "endereco": "Fazenda Abreu, 33\nNova Pampulha\n43943613 Rios / AM",
#     "telefone": "+55 11 3040 2546"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e6",
#     "nome": "Anna Liz Barbosa",
#     "email": "ssales@example.net",
#     "endereco": "Praia Vinícius Pacheco, 3\nVila Independencia 2ª Seção\n62610228 Aragão / RS",
#     "telefone": "(071) 2316-0410"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e7",
#     "nome": "Mateus Vasconcelos",
#     "email": "uramos@example.net",
#     "endereco": "Vila de Farias\nVila Santo Antônio\n90119034 Ferreira do Norte / MA",
#     "telefone": "+55 84 7919 5496"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e8",
#     "nome": "Juliana Azevedo",
#     "email": "ccasa-grande@example.org",
#     "endereco": "Favela de Freitas, 40\nSão Jorge 1ª Seção\n09699-492 Nunes do Campo / RJ",
#     "telefone": "11 0050 9938"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1e9",
#     "nome": "Sr. Nathan Fonseca",
#     "email": "isabelfogaca@example.org",
#     "endereco": "Praça Guerra, 98\nSão Cristóvão\n09000749 Silveira / PA",
#     "telefone": "(084) 5605-7564"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ea",
#     "nome": "Murilo Fernandes",
#     "email": "emanuel77@example.org",
#     "endereco": "Vale de da Mota, 7\nBoa Vista\n66965504 Dias dos Dourados / AP",
#     "telefone": "+55 (011) 0993-2742"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1eb",
#     "nome": "Isabelly Camargo",
#     "email": "ufreitas@example.org",
#     "endereco": "Ladeira Júlia Câmara, 89\nVila Dos Anjos\n84181923 Câmara do Oeste / CE",
#     "telefone": "+55 81 6188-8163"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ec",
#     "nome": "Sr. Benjamim Sá",
#     "email": "tda-costa@example.net",
#     "endereco": "Lago de Novais, 67\nGuaratã\n49770-636 Camargo / RR",
#     "telefone": "71 6980-0230"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ed",
#     "nome": "Julia Cavalcanti",
#     "email": "vitor-gabriel96@example.net",
#     "endereco": "Recanto Lara Ramos\nVila Boa Vista\n31652-163 Moura / MA",
#     "telefone": "(084) 7730-7428"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ee",
#     "nome": "Srta. Maria Vieira",
#     "email": "dmontenegro@example.net",
#     "endereco": "Vereda Silva, 32\nVila Nova Gameleira 3ª Seção\n54486103 Rezende de Caldeira / AC",
#     "telefone": "+55 41 9131 4022"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ef",
#     "nome": "Diogo Cavalcante",
#     "email": "lorenzo67@example.net",
#     "endereco": "Recanto Vitor Hugo Freitas, 31\nBetânia\n00490-061 Nogueira Paulista / SC",
#     "telefone": "+55 (071) 8757 2123"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f0",
#     "nome": "Dr. Bruno Carvalho",
#     "email": "portoanna-liz@example.com",
#     "endereco": "Lagoa de Pinto, 538\nSanto André\n59967199 Brito de da Cruz / MT",
#     "telefone": "+55 (041) 5921 9238"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f1",
#     "nome": "Dom Dias",
#     "email": "clarice95@example.net",
#     "endereco": "Vale de Ribeiro, 17\nGrota\n13126-447 Montenegro / PE",
#     "telefone": "(031) 1041 0416"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f2",
#     "nome": "Vinícius Guerra",
#     "email": "theodoro62@example.net",
#     "endereco": "Setor de da Paz, 2\nParque São Pedro\n18597-654 Alves / RO",
#     "telefone": "+55 (081) 2299-4046"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f3",
#     "nome": "Clarice Moura",
#     "email": "aylla83@example.net",
#     "endereco": "Viaduto Ferreira, 27\nFlamengo\n24798-844 Dias do Campo / RS",
#     "telefone": "(021) 8114 5509"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f4",
#     "nome": "Nicole Ribeiro",
#     "email": "da-matagabriel@example.org",
#     "endereco": "Núcleo Pereira\nNova America\n93581-437 Rocha da Serra / AP",
#     "telefone": "+55 (081) 7537 0195"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f5",
#     "nome": "Rafaela Cardoso",
#     "email": "bentoviana@example.org",
#     "endereco": "Travessa da Cruz, 96\nZilah Sposito\n83284250 Peixoto da Mata / DF",
#     "telefone": "+55 (051) 1309-8691"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f6",
#     "nome": "Alice Rezende",
#     "email": "tpires@example.net",
#     "endereco": "Praia Sofia Abreu, 85\nConjunto Paulo Vi\n98417602 da Cruz / MT",
#     "telefone": "+55 61 8917-4160"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f7",
#     "nome": "Brenda da Conceição",
#     "email": "teixeirasophie@example.org",
#     "endereco": "Vale de Brito, 72\nGranja De Freitas\n69407-399 Nunes / RO",
#     "telefone": "81 2749-6442"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f8",
#     "nome": "Mateus Gonçalves",
#     "email": "da-conceicaolorenzo@example.com",
#     "endereco": "Viaduto Costela, 94\nSão Gonçalo\n75278010 Fogaça / TO",
#     "telefone": "+55 (084) 2632-5522"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1f9",
#     "nome": "Sr. Lucas Cavalcanti",
#     "email": "dda-cunha@example.org",
#     "endereco": "Viela Melissa Borges, 48\nVila Madre Gertrudes 4ª Seção\n84632396 Machado de Goiás / SE",
#     "telefone": "51 9022 1124"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1fa",
#     "nome": "Otávio Gomes",
#     "email": "ceciliarios@example.com",
#     "endereco": "Conjunto Clarice Rios, 24\nNossa Senhora Da Conceição\n23612197 Camargo / MG",
#     "telefone": "71 5503 5138"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1fb",
#     "nome": "Heitor Costela",
#     "email": "sfreitas@example.net",
#     "endereco": "Estrada Peixoto, 83\nHorto\n02774321 Alves / MA",
#     "telefone": "+55 51 9395 5809"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1fc",
#     "nome": "Dr. Joaquim Guerra",
#     "email": "moreiramaria-clara@example.com",
#     "endereco": "Residencial Dias, 75\nPantanal\n95521-329 Vasconcelos Alegre / MG",
#     "telefone": "11 5919-6871"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1fd",
#     "nome": "Milena Machado",
#     "email": "hsouza@example.net",
#     "endereco": "Largo Oliveira, 51\nAraguaia\n52135148 Castro de Souza / AP",
#     "telefone": "(051) 9034 6002"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1fe",
#     "nome": "Júlia da Conceição",
#     "email": "joao-gabriel96@example.net",
#     "endereco": "Feira Gomes\nVila Nova Gameleira 2ª Seção\n54259299 Ferreira / SE",
#     "telefone": "0800-514-0790"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a1ff",
#     "nome": "Sr. Gael Farias",
#     "email": "bpacheco@example.com",
#     "endereco": "Travessa Eloá Mendes\nSerrano\n65756338 Caldeira Grande / RS",
#     "telefone": "0900-504-7656"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a200",
#     "nome": "Stella Sá",
#     "email": "helenacirino@example.com",
#     "endereco": "Passarela Davi Lucas Ferreira, 66\nJardim Do Vale\n78246741 Rezende / RS",
#     "telefone": "+55 (021) 7546 8598"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a201",
#     "nome": "Ravy das Neves",
#     "email": "ana-julia96@example.net",
#     "endereco": "Largo de Rodrigues\nVila Minaslandia\n88466-788 Gonçalves Grande / SP",
#     "telefone": "(051) 6308 5419"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a202",
#     "nome": "Nina Gonçalves",
#     "email": "vinicius73@example.net",
#     "endereco": "Morro de Nascimento, 2\nVila Aeroporto Jaraguá\n36090-535 Cassiano do Galho / MA",
#     "telefone": "+55 31 0400-4324"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a203",
#     "nome": "Ian Cavalcanti",
#     "email": "dborges@example.net",
#     "endereco": "Travessa Rafael Câmara, 37\nCentro\n35796-231 Moura de Vieira / PR",
#     "telefone": "(071) 6267-9492"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a204",
#     "nome": "Maya Rodrigues",
#     "email": "icamargo@example.com",
#     "endereco": "Feira da Mata, 77\nCanadá\n21928-726 Cavalcante / AM",
#     "telefone": "+55 (031) 5565 1582"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a205",
#     "nome": "Heloísa Vargas",
#     "email": "nicolas12@example.net",
#     "endereco": "Residencial da Rocha, 7\nPrado\n04265340 Costa Grande / RJ",
#     "telefone": "11 6521 5347"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a206",
#     "nome": "Enrico Camargo",
#     "email": "lara51@example.org",
#     "endereco": "Área de Machado, 949\nVila Nova Gameleira 3ª Seção\n97889-744 Costela / GO",
#     "telefone": "0500-893-5566"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a207",
#     "nome": "Henry Ferreira",
#     "email": "fernandamonteiro@example.org",
#     "endereco": "Campo Alves\nVila Pilar\n73284239 Cavalcante / PI",
#     "telefone": "(084) 9282-1495"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a208",
#     "nome": "Breno Moreira",
#     "email": "saradias@example.com",
#     "endereco": "Distrito de Duarte, 869\nJardim Do Vale\n42031083 Ramos / PI",
#     "telefone": "0800 368 3253"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a209",
#     "nome": "Dr. Luan Pires",
#     "email": "catarinada-rosa@example.com",
#     "endereco": "Viaduto de Garcia, 84\nAndiroba\n10795405 Mendonça / PR",
#     "telefone": "(041) 9244 6928"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a20a",
#     "nome": "Henry Gabriel da Mota",
#     "email": "henry91@example.net",
#     "endereco": "Estrada Benicio Silva, 72\nLeonina\n92398-578 Cavalcante de Pires / MA",
#     "telefone": "84 3590-1579"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a20b",
#     "nome": "Evelyn Carvalho",
#     "email": "azevedoarthur-gabriel@example.net",
#     "endereco": "Vereda de Costela, 15\nDiamante\n76507651 Rodrigues de Sousa / CE",
#     "telefone": "0500-016-6006"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a20c",
#     "nome": "Cecilia Moura",
#     "email": "souzaantonella@example.net",
#     "endereco": "Vale de Fogaça, 20\nCaiçara - Adelaide\n33335967 Pacheco do Norte / AM",
#     "telefone": "+55 (061) 5423-1789"
#   },
#   {
#     "_id": "674a8c50d1e62a839cf8a20d",
#     "nome": "Isadora Pastor",
#     "email": "aparecidaayla@example.com",
#     "endereco": "Esplanada Rafael Novais, 744\nDelta\n26728-310 Lima de das Neves / DF",
#     "telefone": "0300-066-4281"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a309",
#     "nome": "Guilherme Borges",
#     "email": "ribeirolais@example.com",
#     "endereco": "Praça de Pimenta, 4\nUnião\n23453-309 Rodrigues das Flores / RS",
#     "telefone": "+55 (021) 2771-1334"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30a",
#     "nome": "Luiz Otávio Melo",
#     "email": "helenapacheco@example.org",
#     "endereco": "Quadra Fonseca, 47\nLuxemburgo\n98011-834 Moreira de Minas / CE",
#     "telefone": "+55 (071) 8703 7267"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30b",
#     "nome": "Lívia da Mota",
#     "email": "luiz-henrique67@example.net",
#     "endereco": "Lagoa Albuquerque, 544\nSão Gabriel\n30086541 Siqueira do Amparo / SC",
#     "telefone": "0500-845-0702"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30c",
#     "nome": "Emilly Abreu",
#     "email": "luiz-gustavo13@example.com",
#     "endereco": "Vale Isadora Camargo, 73\nVila Piratininga Venda Nova\n31736-614 Porto / RN",
#     "telefone": "31 3627-0646"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30d",
#     "nome": "Maria Liz Leão",
#     "email": "edas-neves@example.org",
#     "endereco": "Morro Garcia, 8\nVila Petropolis\n68290-875 Fernandes do Amparo / PR",
#     "telefone": "(031) 9578 0106"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30e",
#     "nome": "Thomas Cassiano",
#     "email": "costaalicia@example.com",
#     "endereco": "Pátio Luiz Gustavo Gonçalves, 98\nCopacabana\n70749069 Sales de Novais / DF",
#     "telefone": "(084) 3909 3489"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a30f",
#     "nome": "Léo Oliveira",
#     "email": "cmontenegro@example.org",
#     "endereco": "Conjunto de Fogaça, 7\nCardoso\n90728483 Macedo / RO",
#     "telefone": "+55 (051) 4085-3324"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a310",
#     "nome": "Sr. Oliver Macedo",
#     "email": "dda-conceicao@example.net",
#     "endereco": "Aeroporto Otávio Silva, 5\nPetropolis\n68499-974 Garcia das Flores / RN",
#     "telefone": "(031) 8654-7032"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a311",
#     "nome": "Fernando Sá",
#     "email": "tmendonca@example.com",
#     "endereco": "Loteamento Ágatha Sales, 731\nColégio Batista\n81991-371 Fonseca de Duarte / SE",
#     "telefone": "51 7900 1934"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a312",
#     "nome": "Giovanna Gomes",
#     "email": "castromariah@example.net",
#     "endereco": "Aeroporto Silva, 45\nVila Betânia\n21995-672 Cassiano / BA",
#     "telefone": "+55 (071) 2708 5368"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a313",
#     "nome": "Alexia Aparecida",
#     "email": "pastorjose-pedro@example.com",
#     "endereco": "Praça de Sales, 74\nOlhos D'água\n57977-043 Dias do Amparo / AP",
#     "telefone": "+55 84 6562-4049"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a314",
#     "nome": "Ryan Farias",
#     "email": "leandrosampaio@example.org",
#     "endereco": "Largo de Fogaça, 2\nBom Jesus\n74578959 Rodrigues da Mata / MA",
#     "telefone": "11 5199 9224"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a315",
#     "nome": "Sr. Nathan Ribeiro",
#     "email": "cardosomanuella@example.com",
#     "endereco": "Praça das Neves\nBuritis\n25452-467 da Luz / MA",
#     "telefone": "+55 21 1494 5586"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a316",
#     "nome": "Rael Barbosa",
#     "email": "sophielima@example.net",
#     "endereco": "Avenida de da Rosa, 19\nSantana Do Cafezal\n06410858 da Luz / AP",
#     "telefone": "71 3970-9690"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a317",
#     "nome": "Sara Rocha",
#     "email": "gustavogomes@example.com",
#     "endereco": "Jardim Emanuel da Paz, 17\nConjunto São Francisco De Assis\n79408047 Duarte das Pedras / TO",
#     "telefone": "+55 41 3998-5192"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a318",
#     "nome": "Mateus Andrade",
#     "email": "eramos@example.org",
#     "endereco": "Vale de Andrade, 7\nMinaslandia\n92063-540 Jesus de Macedo / CE",
#     "telefone": "31 0951 3785"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a319",
#     "nome": "Henry Marques",
#     "email": "sarah35@example.com",
#     "endereco": "Distrito de Cavalcante\nBiquinhas\n05483655 Cirino / RO",
#     "telefone": "+55 (081) 9330 7640"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31a",
#     "nome": "Maria Alice da Rosa",
#     "email": "edas-neves@example.org",
#     "endereco": "Parque Andrade\nZilah Sposito\n00237-546 Cavalcante / PE",
#     "telefone": "+55 31 5467 9571"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31b",
#     "nome": "Thales Cavalcanti",
#     "email": "qfreitas@example.com",
#     "endereco": "Área Nunes, 42\nBiquinhas\n46305-656 da Rocha de Goiás / SC",
#     "telefone": "+55 (084) 4346 8468"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31c",
#     "nome": "Igor da Rocha",
#     "email": "leaomatheus@example.org",
#     "endereco": "Travessa de da Mata, 41\nGrotinha\n37951042 Machado das Pedras / RS",
#     "telefone": "+55 51 4228 4048"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31d",
#     "nome": "Felipe Dias",
#     "email": "da-rochagustavo@example.org",
#     "endereco": "Feira Alves, 8\nNova Cachoeirinha\n83888065 Cirino do Oeste / RJ",
#     "telefone": "+55 11 0341-4523"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31e",
#     "nome": "Ian Nunes",
#     "email": "vasconcelosmaria-sophia@example.com",
#     "endereco": "Sítio de Dias, 69\nNova Vista\n24400-091 Cavalcante / PR",
#     "telefone": "21 5130 3315"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a31f",
#     "nome": "Maria Sophia Caldeira",
#     "email": "carvalhoisaque@example.net",
#     "endereco": "Morro de Cardoso, 2\nPrimeiro De Maio\n17738318 Pacheco de Garcia / AM",
#     "telefone": "+55 (081) 7774 2302"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a320",
#     "nome": "Arthur Gabriel da Cruz",
#     "email": "pda-rocha@example.org",
#     "endereco": "Travessa Rodrigues, 74\nDas Industrias I\n72071745 Viana / PI",
#     "telefone": "81 0536-2237"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a321",
#     "nome": "Kevin Dias",
#     "email": "nda-cruz@example.net",
#     "endereco": "Quadra Ryan Pimenta, 8\nSavassi\n46343-399 Guerra / RR",
#     "telefone": "(021) 9284-1409"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a322",
#     "nome": "Davi da Paz",
#     "email": "lopesisabela@example.net",
#     "endereco": "Distrito Davi Miguel Rodrigues\nConjunto Celso Machado\n13734-948 da Luz dos Dourados / PE",
#     "telefone": "+55 (031) 0951 8163"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a323",
#     "nome": "Marcos Vinicius Correia",
#     "email": "anna-liz58@example.net",
#     "endereco": "Avenida de Castro, 30\nBeija Flor\n90182659 Vasconcelos / MS",
#     "telefone": "31 3914 5845"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a324",
#     "nome": "Maria Eduarda da Luz",
#     "email": "davi-miguel24@example.org",
#     "endereco": "Sítio de Silveira, 75\nSanta Rita\n75670-649 Pacheco das Flores / AM",
#     "telefone": "+55 31 8763-8876"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a325",
#     "nome": "Theodoro Souza",
#     "email": "da-luzbryan@example.com",
#     "endereco": "Núcleo Anthony Gonçalves, 48\nDiamante\n09370716 Caldeira de Martins / PA",
#     "telefone": "(031) 0650 0643"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a326",
#     "nome": "Brayan Casa Grande",
#     "email": "vda-cunha@example.net",
#     "endereco": "Morro de Almeida, 32\nNovo São Lucas\n63778717 Ribeiro de Nunes / PB",
#     "telefone": "+55 61 6942 9549"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a327",
#     "nome": "Sr. Yuri Porto",
#     "email": "levi26@example.org",
#     "endereco": "Lago Alves, 879\nVitoria\n20634-635 Ramos / RS",
#     "telefone": "+55 (031) 7612 5528"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a328",
#     "nome": "Catarina Ferreira",
#     "email": "alvesana-beatriz@example.net",
#     "endereco": "Rua Davi Lucas Rios, 66\nRenascença\n78658753 Freitas Verde / PI",
#     "telefone": "(061) 5045-9884"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a329",
#     "nome": "Sr. Theodoro Nascimento",
#     "email": "rcostela@example.org",
#     "endereco": "Vila Hellena Vasconcelos, 5\nVila Santa Rosa\n03469374 Gomes / MG",
#     "telefone": "+55 (084) 2496-2226"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32a",
#     "nome": "Emilly Rocha",
#     "email": "meloisabela@example.net",
#     "endereco": "Aeroporto Maria Helena Souza\nVila Ecológica\n71519-767 Carvalho de Rodrigues / DF",
#     "telefone": "+55 (084) 7041-6533"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32b",
#     "nome": "Enzo Marques",
#     "email": "levioliveira@example.org",
#     "endereco": "Loteamento Macedo\nMaria Virgínia\n57967-781 Viana / BA",
#     "telefone": "+55 (084) 8246 2977"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32c",
#     "nome": "Dr. Arthur Moraes",
#     "email": "ada-cruz@example.org",
#     "endereco": "Rua Manuella Fernandes, 75\nChácara Leonina\n22412791 Guerra / BA",
#     "telefone": "(084) 6635-0303"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32d",
#     "nome": "Dr. Apollo Moreira",
#     "email": "fnovais@example.org",
#     "endereco": "Jardim Laís da Mata, 69\nVila Olhos D'água\n16652-186 Vargas / ES",
#     "telefone": "(071) 3608-4570"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32e",
#     "nome": "Dra. Isabelly Pimenta",
#     "email": "pedro-lucas33@example.org",
#     "endereco": "Distrito de Campos, 39\nVila Batik\n87975-577 Teixeira Grande / AL",
#     "telefone": "61 3741 9955"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a32f",
#     "nome": "Alice Gomes",
#     "email": "benjaminoliveira@example.net",
#     "endereco": "Chácara Fogaça, 237\nSão Bento\n03680563 Martins da Mata / PR",
#     "telefone": "+55 (011) 1920 7187"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a330",
#     "nome": "Elisa Aparecida",
#     "email": "francisco96@example.com",
#     "endereco": "Vila de Casa Grande, 536\nNazare\n93427829 Pastor do Sul / PB",
#     "telefone": "(021) 9102 1083"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a331",
#     "nome": "Milena Gomes",
#     "email": "ujesus@example.com",
#     "endereco": "Alameda de Pimenta\nSão Jorge 3ª Seção\n65362-620 Pereira / MG",
#     "telefone": "(071) 3722 7497"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a332",
#     "nome": "Matteo Rios",
#     "email": "felipe39@example.org",
#     "endereco": "Área João Gabriel Vasconcelos\nVila Nova Cachoeirinha 1ª Seção\n07028329 Cunha / DF",
#     "telefone": "0500 155 9172"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a333",
#     "nome": "Nathan Nunes",
#     "email": "sgomes@example.net",
#     "endereco": "Sítio Câmara, 5\nBonsucesso\n68552-724 Albuquerque / RS",
#     "telefone": "+55 41 5699 4926"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a334",
#     "nome": "Ágatha Duarte",
#     "email": "pedro-lucas47@example.net",
#     "endereco": "Distrito Garcia, 27\nAguas Claras\n04943048 Ferreira / RO",
#     "telefone": "0900-483-4143"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a335",
#     "nome": "Liz Andrade",
#     "email": "da-pazotto@example.org",
#     "endereco": "Recanto de Porto, 2\nMirtes\n96290562 Moreira de Goiás / BA",
#     "telefone": "(011) 7903-8859"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a336",
#     "nome": "Murilo Aparecida",
#     "email": "milena63@example.org",
#     "endereco": "Recanto José Miguel Nunes, 78\nConjunto Jardim Filadélfia\n35383-421 da Rosa da Serra / MG",
#     "telefone": "(081) 6648 8953"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a337",
#     "nome": "Enzo Casa Grande",
#     "email": "lvargas@example.org",
#     "endereco": "Aeroporto Thales Duarte, 82\nSanta Inês\n21249-910 Silveira / RS",
#     "telefone": "+55 (084) 0885 6278"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a338",
#     "nome": "Sr. Juan das Neves",
#     "email": "alicia73@example.net",
#     "endereco": "Rodovia de Lopes, 9\nSanta Rita\n73776371 Alves / MG",
#     "telefone": "+55 (021) 6155 6580"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a339",
#     "nome": "Dom das Neves",
#     "email": "vitor53@example.com",
#     "endereco": "Viaduto de Freitas, 34\nNossa Senhora De Fátima\n02921555 Gonçalves do Sul / SE",
#     "telefone": "+55 (021) 7624-2900"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33a",
#     "nome": "Breno Camargo",
#     "email": "mouradanilo@example.net",
#     "endereco": "Aeroporto de Lima, 293\nVila São Francisco\n77612-705 Monteiro / AP",
#     "telefone": "+55 (084) 1529 2554"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33b",
#     "nome": "Ana Liz da Conceição",
#     "email": "arthur-miguel18@example.org",
#     "endereco": "Alameda Luiz Gustavo Novaes, 9\nJardim Atlântico\n82108507 da Cruz das Flores / MS",
#     "telefone": "+55 21 5515 1402"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33c",
#     "nome": "Dr. Mateus Cavalcante",
#     "email": "luancirino@example.net",
#     "endereco": "Parque Brito, 45\nVila Nova Gameleira 3ª Seção\n16011525 Duarte Paulista / SE",
#     "telefone": "(021) 0984 0126"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33d",
#     "nome": "Luiz Felipe da Paz",
#     "email": "efogaca@example.net",
#     "endereco": "Residencial Camargo, 4\nVila Jardim Montanhes\n65137-992 Freitas Paulista / MT",
#     "telefone": "(041) 6565-6284"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33e",
#     "nome": "Vitor Hugo Nogueira",
#     "email": "nogueiraleo@example.com",
#     "endereco": "Favela Bella da Luz, 7\nSaudade\n49298-883 Dias do Galho / PB",
#     "telefone": "21 6068-3316"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a33f",
#     "nome": "Nicolas Casa Grande",
#     "email": "catarina59@example.net",
#     "endereco": "Sítio de Fonseca, 38\nVila Engenho Nogueira\n96377-247 Vasconcelos / PI",
#     "telefone": "(051) 6190-9380"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a340",
#     "nome": "Alícia Cavalcante",
#     "email": "rsantos@example.com",
#     "endereco": "Vereda Agatha Leão, 90\nVila Sumaré\n84168-966 Santos / MT",
#     "telefone": "51 6869 3808"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a341",
#     "nome": "Fernando Lima",
#     "email": "theocavalcante@example.net",
#     "endereco": "Feira Campos, 55\nSão Benedito\n28143771 da Mata / ES",
#     "telefone": "+55 21 6228-6280"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a342",
#     "nome": "Dr. Vinícius Moreira",
#     "email": "sophie95@example.net",
#     "endereco": "Recanto de Castro, 7\nVila Santa Monica 2ª Seção\n88532913 da Rosa da Prata / SP",
#     "telefone": "+55 11 7541-1636"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a343",
#     "nome": "Daniel Leão",
#     "email": "barbosabianca@example.org",
#     "endereco": "Estação de Pereira, 66\nManacas\n85873682 Campos de da Cruz / RR",
#     "telefone": "61 4917 3363"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a344",
#     "nome": "Vitor Carvalho",
#     "email": "breno26@example.org",
#     "endereco": "Vale de Casa Grande, 916\nVila Antena Montanhês\n16145-734 Monteiro / GO",
#     "telefone": "51 7811 5256"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a345",
#     "nome": "Letícia Peixoto",
#     "email": "luiz-henriquepereira@example.org",
#     "endereco": "Estação de Rodrigues, 153\nEstoril\n82997322 Novaes de da Costa / MT",
#     "telefone": "11 5339 7249"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a346",
#     "nome": "Kevin Peixoto",
#     "email": "fsampaio@example.com",
#     "endereco": "Estrada de Alves, 37\nJatobá\n12519907 Correia / MT",
#     "telefone": "31 6426 3422"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a347",
#     "nome": "Léo Barbosa",
#     "email": "benicio64@example.com",
#     "endereco": "Recanto de Gonçalves, 49\nVila São Rafael\n72875-440 Gomes / PE",
#     "telefone": "+55 61 8295-3226"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a348",
#     "nome": "Yan Cirino",
#     "email": "isabellacunha@example.org",
#     "endereco": "Residencial de Borges\nMaravilha\n55188-453 Freitas / TO",
#     "telefone": "0800 881 7171"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a349",
#     "nome": "Juliana Martins",
#     "email": "fcaldeira@example.com",
#     "endereco": "Via de da Mata, 42\nVila Antena Montanhês\n81066022 Garcia do Norte / SC",
#     "telefone": "+55 (011) 7207 7795"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34a",
#     "nome": "Bianca Sousa",
#     "email": "goncalvesmirella@example.com",
#     "endereco": "Travessa Azevedo, 94\nRibeiro De Abreu\n77893-871 Azevedo / RR",
#     "telefone": "(021) 0599 1139"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34b",
#     "nome": "Nina Camargo",
#     "email": "pastordavi@example.com",
#     "endereco": "Quadra Nascimento, 89\nManacas\n82524202 Sousa da Serra / AL",
#     "telefone": "+55 31 2271 7875"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34c",
#     "nome": "Davi Miguel Aparecida",
#     "email": "da-matafernanda@example.com",
#     "endereco": "Avenida Leão, 68\nCanadá\n77509932 Mendes do Oeste / PB",
#     "telefone": "+55 (081) 3012-9800"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34d",
#     "nome": "Vinícius Monteiro",
#     "email": "maria-fernanda81@example.net",
#     "endereco": "Quadra de Mendes, 383\nParaíso\n07344-647 Fogaça / PR",
#     "telefone": "(031) 1689-0685"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34e",
#     "nome": "Yan da Rocha",
#     "email": "mcosta@example.net",
#     "endereco": "Esplanada de Nunes, 5\nFlavio De Oliveira\n89412-174 Mendes / GO",
#     "telefone": "+55 71 4975 7552"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a34f",
#     "nome": "Evelyn Melo",
#     "email": "valentinanunes@example.com",
#     "endereco": "Aeroporto de da Mata\nVila Madre Gertrudes 3ª Seção\n01806694 Mendes / SE",
#     "telefone": "(041) 3531 3338"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a350",
#     "nome": "Maria Alice Teixeira",
#     "email": "larissacaldeira@example.com",
#     "endereco": "Condomínio Sousa, 5\nBelvedere\n26786-931 Sampaio / AM",
#     "telefone": "0800 755 8754"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a351",
#     "nome": "Sr. Cauã das Neves",
#     "email": "heloisa78@example.org",
#     "endereco": "Colônia Luan Pimenta, 85\nCônego Pinheiro 1ª Seção\n86290454 Sá do Amparo / AC",
#     "telefone": "+55 (061) 0978-6402"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a352",
#     "nome": "Sra. Cecília Mendonça",
#     "email": "isaac25@example.com",
#     "endereco": "Loteamento Leandro da Cruz\nÁpia\n22001-393 Nunes / RS",
#     "telefone": "71 0074 4553"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a353",
#     "nome": "Isabel Campos",
#     "email": "osantos@example.org",
#     "endereco": "Via de Cardoso, 46\nFrei Leopoldo\n71789-217 Fogaça / AP",
#     "telefone": "81 9442 8935"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a354",
#     "nome": "Arthur Gabriel Pereira",
#     "email": "monteiromaria-flor@example.net",
#     "endereco": "Sítio Cunha, 498\nVila Da Paz\n43342-453 Cassiano Paulista / GO",
#     "telefone": "61 2328-5096"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a355",
#     "nome": "Otto Viana",
#     "email": "ceciliada-rosa@example.com",
#     "endereco": "Área Luan Abreu, 602\nSanta Branca\n68314840 Sampaio de Nunes / PR",
#     "telefone": "+55 41 5714-4566"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a356",
#     "nome": "Nicole Abreu",
#     "email": "lorenzo92@example.com",
#     "endereco": "Rua Sarah da Mata, 13\nCéu Azul\n71758-270 Santos / SP",
#     "telefone": "61 2356 2794"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a357",
#     "nome": "Rafael Lopes",
#     "email": "csilva@example.net",
#     "endereco": "Residencial João Pedro Fogaça, 8\nTiradentes\n60181004 Pinto / RN",
#     "telefone": "84 9239-7022"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a358",
#     "nome": "Dr. Kaique Teixeira",
#     "email": "gabriel78@example.org",
#     "endereco": "Recanto Monteiro, 4\nBraúnas\n60345-786 Oliveira / SC",
#     "telefone": "+55 31 2018-9320"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a359",
#     "nome": "Calebe Ribeiro",
#     "email": "emanuella87@example.com",
#     "endereco": "Lago de Pimenta\nConjunto Celso Machado\n06562135 Carvalho do Galho / AC",
#     "telefone": "(071) 0407 8067"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35a",
#     "nome": "Marcela Ramos",
#     "email": "ana-vitoria82@example.net",
#     "endereco": "Rua de da Rocha\nVila Independencia 1ª Seção\n50384806 Rodrigues / SE",
#     "telefone": "(041) 7402-3802"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35b",
#     "nome": "Sr. Anthony Gabriel Costa",
#     "email": "theosousa@example.net",
#     "endereco": "Jardim Viana, 149\nJatobá\n63818-192 Casa Grande de Goiás / PI",
#     "telefone": "84 4233 7944"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35c",
#     "nome": "Luiz Otávio Gonçalves",
#     "email": "valentina65@example.org",
#     "endereco": "Conjunto de Gomes, 22\nAlto Das Antenas\n75076503 Lopes da Serra / MS",
#     "telefone": "(031) 9402-2395"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35d",
#     "nome": "Gustavo Henrique Montenegro",
#     "email": "gda-costa@example.net",
#     "endereco": "Favela Rezende, 20\nProvidencia\n90115-985 da Mata Alegre / RO",
#     "telefone": "+55 (084) 8520-4127"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35e",
#     "nome": "Ana Cecília Fogaça",
#     "email": "davi97@example.com",
#     "endereco": "Núcleo Hadassa Brito, 2\nSerra Verde\n46949-868 Barbosa / GO",
#     "telefone": "31 2473 2353"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a35f",
#     "nome": "Renan Marques",
#     "email": "borgesrhavi@example.com",
#     "endereco": "Jardim de Alves\nProvidencia\n83047824 Porto da Praia / MS",
#     "telefone": "(051) 0048 2008"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a360",
#     "nome": "Vitor Hugo da Mota",
#     "email": "viniciusalmeida@example.com",
#     "endereco": "Colônia de Pacheco, 485\nVila Da Luz\n25842226 Camargo / RR",
#     "telefone": "(071) 2189-8327"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a361",
#     "nome": "João Guilherme Barbosa",
#     "email": "da-costamaria-luisa@example.net",
#     "endereco": "Setor de Castro, 375\nCruzeiro\n11027102 Pereira das Flores / RN",
#     "telefone": "0900-910-8632"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a362",
#     "nome": "Caroline Porto",
#     "email": "jcorreia@example.net",
#     "endereco": "Campo de da Mata, 6\nTupi B\n55947487 Lima de Garcia / PR",
#     "telefone": "+55 (071) 8793-8972"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a363",
#     "nome": "Bianca Montenegro",
#     "email": "maria-luisaaraujo@example.com",
#     "endereco": "Passarela Novaes\nNossa Senhora Do Rosário\n61870-370 Azevedo da Mata / MA",
#     "telefone": "11 8976-5028"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a364",
#     "nome": "Davi Mendes",
#     "email": "castrolaura@example.org",
#     "endereco": "Condomínio Cirino, 933\nSão Tomaz\n07882-679 Cunha do Oeste / RO",
#     "telefone": "+55 51 9477 1032"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a365",
#     "nome": "Vitor Gabriel Sá",
#     "email": "cardosojoao-miguel@example.net",
#     "endereco": "Praia João Lucas Nascimento, 71\nVila Formosa\n68782690 Barros de Viana / MT",
#     "telefone": "+55 41 3971-8927"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a366",
#     "nome": "Maria Helena Rocha",
#     "email": "crocha@example.org",
#     "endereco": "Jardim Teixeira, 291\nPrimeiro De Maio\n56490-956 Casa Grande da Serra / RO",
#     "telefone": "+55 (081) 7730-1970"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a367",
#     "nome": "Amanda Fonseca",
#     "email": "da-rosavitor-gabriel@example.org",
#     "endereco": "Favela de da Luz\nLaranjeiras\n34532972 Vargas / PR",
#     "telefone": "+55 (031) 3623 6411"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a368",
#     "nome": "Srta. Marcela Aragão",
#     "email": "vitoria20@example.net",
#     "endereco": "Travessa Pastor, 19\nVila São Gabriel\n05727-849 Borges / PA",
#     "telefone": "+55 (071) 4588-9251"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a369",
#     "nome": "Dra. Agatha Machado",
#     "email": "pmarques@example.com",
#     "endereco": "Campo Oliveira, 3\nAlto Dos Pinheiros\n47251857 Barros de Macedo / RO",
#     "telefone": "41 3387 7675"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a36a",
#     "nome": "Vinícius Santos",
#     "email": "maitepacheco@example.com",
#     "endereco": "Colônia Carvalho\nGoiania\n91386559 Camargo / CE",
#     "telefone": "0300-850-3998"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a36b",
#     "nome": "Sr. André Moraes",
#     "email": "luisa63@example.net",
#     "endereco": "Fazenda de Souza, 70\nVila Minaslandia\n67835-524 Cirino / SE",
#     "telefone": "+55 71 5173 1057"
#   },
#   {
#     "_id": "674a8c96d1e62a839cf8a36c",
#     "nome": "Ian Gomes",
#     "email": "qcamara@example.net",
#     "endereco": "Ladeira de Cardoso, 2\nFuncionários\n74899-660 Andrade / PB",
#     "telefone": "+55 51 3878 0654"
#   },
#   {
#     "_id": "674b4b3801d4422b9aaa9599",
#     "nome": "Brenda Fernandes",
#     "email": "aribeiro@example.net",
#     "endereco": "Lago de da Mata, 2\nSão Benedito\n52990534 da Cunha dos Dourados / SP",
#     "telefone": "31 7795 3772",
# ...
#     "telefone": "+55 81 3526 6945"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e0",
#     "nome": "Arthur Borges",
#     "email": "ana-liz37@example.com",
#     "endereco": "Estação Manuela Martins, 3\nVila Ecológica\n53801605 Campos do Campo / TO",
#     "telefone": "+55 (084) 3422 7657"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e1",
#     "nome": "Luísa Rocha",
#     "email": "luaraviana@example.com",
#     "endereco": "Condomínio Mariane Albuquerque\nSão Salvador\n70889-185 Cardoso / RR",
#     "telefone": "61 8039-1803"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e2",
#     "nome": "Daniel Leão",
#     "email": "gabriela79@example.org",
#     "endereco": "Recanto Miguel Pires\nPiraja\n24874482 da Mata / MT",
#     "telefone": "71 6224-2958"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e3",
#     "nome": "Lorena Ribeiro",
#     "email": "valentim86@example.net",
#     "endereco": "Morro Agatha Melo, 45\nUniverso\n18557216 Rios de Câmara / RR",
#     "telefone": "11 5960-7264"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e4",
#     "nome": "Beatriz da Paz",
#     "email": "luiz-gustavoda-rocha@example.org",
#     "endereco": "Vale de Gomes, 532\nVila São Geraldo\n86422-073 Sampaio de Moura / DF",
#     "telefone": "21 6795 8385"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e5",
#     "nome": "Maria Liz Barbosa",
#     "email": "maite19@example.org",
#     "endereco": "Trevo Davi Miguel da Conceição, 43\nVila Cloris\n72949125 Jesus / AP",
#     "telefone": "+55 21 3784-2550"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e6",
#     "nome": "Ana Luiza Rodrigues",
#     "email": "ryanribeiro@example.net",
#     "endereco": "Colônia Clara Viana, 9\nVila Trinta E Um De Março\n52700351 Duarte do Campo / AC",
#     "telefone": "(041) 6632-8253"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e7",
#     "nome": "Kevin Borges",
#     "email": "bcavalcanti@example.com",
#     "endereco": "Viela Correia, 59\nAlto Barroca\n36033267 Lopes da Serra / ES",
#     "telefone": "84 2994-6587"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e8",
#     "nome": "Laís Jesus",
#     "email": "zmendes@example.org",
#     "endereco": "Esplanada Antônio Rocha, 36\nSaudade\n57141104 Ribeiro dos Dourados / PA",
#     "telefone": "+55 61 2397-6158"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148e9",
#     "nome": "Joana da Rocha",
#     "email": "ndias@example.net",
#     "endereco": "Viaduto Antony Rodrigues, 70\nConjunto Novo Dom Bosco\n26100712 Mendonça / MA",
#     "telefone": "+55 (071) 1314-8021"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ea",
#     "nome": "Joaquim Ribeiro",
#     "email": "maria-flor29@example.net",
#     "endereco": "Lago Cavalcanti, 555\nBernadete\n18027834 Borges de Rocha / DF",
#     "telefone": "81 1516-7324"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148eb",
#     "nome": "Rafaela Peixoto",
#     "email": "jsales@example.org",
#     "endereco": "Praça de Nascimento, 1\nMinas Caixa\n54969978 Novaes das Flores / RR",
#     "telefone": "(041) 8459-7408"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ec",
#     "nome": "Matheus Albuquerque",
#     "email": "foliveira@example.com",
#     "endereco": "Campo Borges, 8\nAraguaia\n76241-283 da Mata / AM",
#     "telefone": "+55 84 5809 4415"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ed",
#     "nome": "Srta. Eduarda Nunes",
#     "email": "souzaliz@example.com",
#     "endereco": "Quadra Bruno Oliveira\nNovo Santa Cecilia\n59504-475 Teixeira Grande / PE",
#     "telefone": "+55 41 8732 4918"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ee",
#     "nome": "Sr. Bernardo Novaes",
#     "email": "isabelly33@example.com",
#     "endereco": "Residencial Luan Dias, 78\nConjunto Novo Dom Bosco\n98129375 Pinto / RR",
#     "telefone": "+55 31 7401-4139"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ef",
#     "nome": "Amanda Garcia",
#     "email": "isaacsampaio@example.org",
#     "endereco": "Residencial de Peixoto, 33\nNossa Senhora De Fátima\n17312362 Moraes / AM",
#     "telefone": "+55 (071) 0379-7475"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f0",
#     "nome": "Maria Fernanda Ramos",
#     "email": "enzosales@example.net",
#     "endereco": "Estrada Fernanda Barbosa, 5\nCamargos\n48888331 Rios do Oeste / PB",
#     "telefone": "(041) 0717 7934"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f1",
#     "nome": "Lara Leão",
#     "email": "emillynovaes@example.org",
#     "endereco": "Setor Lima, 24\nNova Cachoeirinha\n94607-762 Rodrigues / MT",
#     "telefone": "+55 (061) 2113 8317"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f2",
#     "nome": "Bianca Jesus",
#     "email": "danielmoura@example.org",
#     "endereco": "Área Amanda Silva, 845\nVila Sesc\n49513-729 Castro de Jesus / AP",
#     "telefone": "(061) 4192 5070"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f3",
#     "nome": "Srta. Ana Luiza Nunes",
#     "email": "caua22@example.org",
#     "endereco": "Fazenda Monteiro, 13\nConjunto Novo Dom Bosco\n05692-982 Machado dos Dourados / RJ",
#     "telefone": "84 4989-0578"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f4",
#     "nome": "Evelyn Rocha",
#     "email": "clara43@example.com",
#     "endereco": "Aeroporto Ian Garcia, 25\nVila Petropolis\n35051-655 Almeida / RS",
#     "telefone": "0500-402-1550"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f5",
#     "nome": "Isabela da Cruz",
#     "email": "caio53@example.org",
#     "endereco": "Travessa Esther da Rosa, 206\nSanta Amelia\n39166500 Camargo Verde / RR",
#     "telefone": "71 0792-5445"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f6",
#     "nome": "Otto Jesus",
#     "email": "jose-miguel71@example.net",
#     "endereco": "Área João Miguel Dias, 69\nNova Pampulha\n21551743 Pires / MA",
#     "telefone": "0300 588 0834"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f7",
#     "nome": "Melina Sales",
#     "email": "brenoda-cruz@example.org",
#     "endereco": "Vila Letícia Pereira, 74\nPrimeiro De Maio\n87551-812 da Rosa / TO",
#     "telefone": "0900-100-5207"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f8",
#     "nome": "Ana Cecília Siqueira",
#     "email": "gomesmatteo@example.org",
#     "endereco": "Ladeira Fonseca, 6\nConfisco\n63827-745 Cassiano dos Dourados / RJ",
#     "telefone": "0800-119-8644"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148f9",
#     "nome": "Laura Gomes",
#     "email": "luanamonteiro@example.com",
#     "endereco": "Vereda Pastor, 77\nJonas Veiga\n96448-962 Pimenta / MG",
#     "telefone": "(011) 1586-0169"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148fa",
#     "nome": "João Vitor Araújo",
#     "email": "nogueiramaria-cecilia@example.com",
#     "endereco": "Residencial Moreira\nNovo Ouro Preto\n15594-708 da Conceição do Norte / GO",
#     "telefone": "0900-875-9960"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148fb",
#     "nome": "Pedro Lucas Sousa",
#     "email": "erick75@example.net",
#     "endereco": "Fazenda Vieira, 9\nSanta Lúcia\n97710356 Moura da Serra / ES",
#     "telefone": "31 5830 5549"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148fc",
#     "nome": "Melissa Moreira",
#     "email": "caue35@example.net",
#     "endereco": "Aeroporto Luiz Henrique Pacheco\nMorro Dos Macacos\n64454-136 Macedo / RO",
#     "telefone": "+55 (071) 8249-9609"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148fd",
#     "nome": "Pedro Lucas Melo",
#     "email": "thales38@example.org",
#     "endereco": "Feira Mirella da Rocha, 60\nFlavio De Oliveira\n70689359 Dias de Goiás / PR",
#     "telefone": "+55 (011) 9733-6476"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148fe",
#     "nome": "Cecília das Neves",
#     "email": "maria-juliamoura@example.net",
#     "endereco": "Largo Mariah Peixoto\nConcórdia\n75932-003 Ramos Verde / TO",
#     "telefone": "21 0797 5171"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a148ff",
#     "nome": "Benjamim Oliveira",
#     "email": "juliagoncalves@example.net",
#     "endereco": "Travessa de Azevedo, 75\nSão Francisco\n78978-984 Cassiano / PI",
#     "telefone": "84 1053 6878"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14900",
#     "nome": "Sra. Maria Cecília Pires",
#     "email": "valentimcosta@example.org",
#     "endereco": "Fazenda de Carvalho, 9\nMinaslandia\n55209-648 Costela de Goiás / SP",
#     "telefone": "(071) 4529 3023"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14901",
#     "nome": "Maria Laura Novaes",
#     "email": "nathansilva@example.net",
#     "endereco": "Chácara Garcia, 19\nMarilandia\n77823-096 Martins das Flores / GO",
#     "telefone": "+55 (041) 3418 3682"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14902",
#     "nome": "Luiza Vieira",
#     "email": "ravi02@example.net",
#     "endereco": "Distrito Cecília Borges\nNova Cintra\n80468-125 Siqueira / RR",
#     "telefone": "+55 (041) 6239 8042"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14903",
#     "nome": "Luna Barbosa",
#     "email": "gabriela53@example.com",
#     "endereco": "Condomínio Oliveira, 9\nXangri-Lá\n91932-639 Pacheco Verde / SC",
#     "telefone": "51 1046 8274"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14904",
#     "nome": "Brenda da Mota",
#     "email": "maria-fernandaribeiro@example.com",
#     "endereco": "Esplanada de Vieira, 834\nSão Cristóvão\n09457-492 Jesus / AC",
#     "telefone": "51 9219 9889"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14905",
#     "nome": "Rebeca Ferreira",
#     "email": "cunhaarthur@example.com",
#     "endereco": "Praça de Nunes\nSanta Isabel\n79311279 da Paz / AC",
#     "telefone": "0800 882 4281"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14906",
#     "nome": "Ana Sousa",
#     "email": "barbosaraquel@example.org",
#     "endereco": "Praça Diogo Cardoso, 90\nCaiçara - Adelaide\n86882-973 Araújo das Flores / MT",
#     "telefone": "+55 (011) 8810 5408"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14907",
#     "nome": "Dr. Levi Cavalcanti",
#     "email": "duarteenzo-gabriel@example.net",
#     "endereco": "Parque Sousa, 59\nVila Coqueiral\n83502359 Montenegro de Nunes / MS",
#     "telefone": "51 0982 9634"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14908",
#     "nome": "Noah Cirino",
#     "email": "dpires@example.net",
#     "endereco": "Avenida de Gonçalves, 27\nPantanal\n46109261 da Paz de Farias / GO",
#     "telefone": "(071) 3860-1833"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14909",
#     "nome": "Joaquim Peixoto",
#     "email": "domfonseca@example.org",
#     "endereco": "Trevo Nascimento, 34\nVila Coqueiral\n19670134 Marques / GO",
#     "telefone": "(021) 7392-8605"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490a",
#     "nome": "Sra. Heloísa Souza",
#     "email": "mirella05@example.net",
#     "endereco": "Fazenda Abreu, 73\nCidade Nova\n30617-295 Cunha / DF",
#     "telefone": "(041) 7255 9693"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490b",
#     "nome": "Melissa Pacheco",
#     "email": "vasconcelosmelina@example.net",
#     "endereco": "Estação Maria Liz Camargo, 855\nVila Ipiranga\n65230924 Siqueira / RS",
#     "telefone": "(071) 3870 6606"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490c",
#     "nome": "Liam Brito",
#     "email": "drezende@example.org",
#     "endereco": "Alameda Vieira, 34\nCalifórnia\n85187-829 Vasconcelos / PI",
#     "telefone": "51 3543 0197"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490d",
#     "nome": "Levi Viana",
#     "email": "cecilia82@example.net",
#     "endereco": "Distrito Novais, 887\nVila Madre Gertrudes 2ª Seção\n94082-704 Vieira de Goiás / SP",
#     "telefone": "51 3022 8415"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490e",
#     "nome": "Milena Azevedo",
#     "email": "maraujo@example.com",
#     "endereco": "Alameda da Conceição, 21\nSão Benedito\n03460905 da Rosa / PI",
#     "telefone": "21 5870-6716"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1490f",
#     "nome": "Maria Fernanda Novaes",
#     "email": "lucas28@example.org",
#     "endereco": "Via Aparecida, 16\nZilah Sposito\n87314-548 Rezende / CE",
#     "telefone": "+55 (031) 1292 5901"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14910",
#     "nome": "Bryan da Cunha",
#     "email": "beniciomoura@example.org",
#     "endereco": "Lago Sales, 50\nMarçola\n45793-553 da Cunha / RS",
#     "telefone": "+55 71 7011 2623"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14911",
#     "nome": "Srta. Brenda da Luz",
#     "email": "leticiarezende@example.com",
#     "endereco": "Aeroporto de Garcia, 30\nCanaa\n67879-200 Barros / RN",
#     "telefone": "+55 21 6360 1184"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14912",
#     "nome": "João Gabriel Rocha",
#     "email": "luiz-otavio97@example.org",
#     "endereco": "Quadra João Gabriel Pimenta, 95\nGarças\n80031-925 Cardoso / RN",
#     "telefone": "51 8088 0530"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14913",
#     "nome": "Vinicius Pastor",
#     "email": "beatriz49@example.net",
#     "endereco": "Vale Casa Grande, 34\nBelvedere\n32039082 Pinto da Serra / ES",
#     "telefone": "(084) 2795 4875"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14914",
#     "nome": "Alice Pastor",
#     "email": "anthony32@example.com",
#     "endereco": "Fazenda de Rocha, 24\nConjunto São Francisco De Assis\n26953-526 Caldeira das Flores / TO",
#     "telefone": "0500-304-7920"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14915",
#     "nome": "Cecília Sampaio",
#     "email": "aaragao@example.org",
#     "endereco": "Conjunto de Farias, 178\nVila Minaslandia\n55218-208 Moura Grande / RR",
#     "telefone": "(051) 6044-3243"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14916",
#     "nome": "Pedro Henrique Brito",
#     "email": "sabrinacirino@example.com",
#     "endereco": "Viela Fernanda da Mota, 24\nMariano De Abreu\n11903302 Pimenta dos Dourados / MT",
#     "telefone": "11 6662-7650"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14917",
#     "nome": "Dra. Evelyn Gomes",
#     "email": "rabreu@example.com",
#     "endereco": "Conjunto de Guerra, 54\nTrevo\n62495-521 Siqueira / MA",
#     "telefone": "+55 (081) 7123 8353"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14918",
#     "nome": "Henry Gabriel Albuquerque",
#     "email": "aparecidabrayan@example.net",
#     "endereco": "Setor Ísis da Costa, 85\nJardim Guanabara\n43095-338 Barbosa / CE",
#     "telefone": "+55 81 2097-3949"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a14919",
#     "nome": "Pietro da Conceição",
#     "email": "guerraeloa@example.net",
#     "endereco": "Ladeira de Aragão\nEngenho Nogueira\n01573306 Melo Grande / SP",
#     "telefone": "41 9645 7217"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1491a",
#     "nome": "Diogo Correia",
#     "email": "miguelgarcia@example.com",
#     "endereco": "Travessa Albuquerque, 11\nGrota\n18528-608 Duarte / MS",
#     "telefone": "+55 41 1143-8163"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1491b",
#     "nome": "Cecília Pastor",
#     "email": "britomaria-fernanda@example.org",
#     "endereco": "Loteamento Bento Câmara, 6\nJoão Alfredo\n18135-766 Borges de Sales / AC",
#     "telefone": "(021) 9245 0539"
#   },
#   {
#     "_id": "674cf3f9eeb3778b09a1491c",
#     "nome": "Benjamin Araújo",
#     "email": "ibrito@example.org",
#     "endereco": "Estação Ana Sousa, 16\nTiradentes\n95260743 Vargas / PA",
#     "telefone": "71 1687-4370"
#   }
# ]
#
# Interpretação:
# Os resultados da query mostram as cinco primeiras entradas da coleção "clientes". Aqui estão os detalhes dos clientes:
#
# 1. **Olivia da Cruz**
#    - Email: ecamara@example.com
#    - Endereço: Praça Machado, 53, Araguaia, 49830712 Melo da Mata / RO
#    - Telefone: +55 (011) 2116-1910
#
# 2. **Lívia Gomes**
#    - Email: limaluana@example.org
#    - Endereço: Área de Sá, 21, Bandeirantes, 82336000 Castro de Andrade / RN
#    - Telefone: 51 9740 1897
#
# 3. **Srta. Maria Alice Montenegro**
#    - Email: eloahlima@example.net
#    - Endereço: Ladeira Mendes, 88, Piratininga, 46082-907 Silva / SP
#    - Telefone: +55 81 2789-6543
#
# 4. **Aylla Gonçalves**
#    - Email: thales04@example.net
#    - Endereço: Vila de Lima, 43, Vila Mangueiras, 93905548 Nunes / RO
#    - Telefone: 31 7059-2162
#
# 5. **Sophie Novaes**
#    - Email: marianecasa-grande@example.org
#    - Endereço: Trevo de Castro, 98, Novo Ouro Preto, 94112010 Viana / CE
#    - Telefone: 0300 868 4934
#
# Esses dados incluem informações sobre o nome, email, endereço e telefone de cada cliente.
#
# Como os resultados incluem múltiplos clientes e suas informações, um gráfico de barras poderia ser útil para visualizar a quantidade de clientes por estado ou cidade, caso você tenha dados adicionais sobre a localização. No entanto, para os dados apresentados, um gráfico não é aplicável, pois não há uma métrica numérica ou categórica a ser comparada visualmente.
# Nenhum gráfico gerado.
